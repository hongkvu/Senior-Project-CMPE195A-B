# %% [markdown]
# <a href="https://colab.research.google.com/github/Diem-Vu/Cryptology/blob/main/CoAtNet_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Sun Nov 20 05:45:53 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   75C    P0    32W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install tensorflow-gpu
# !pip install einops
# !pip install torch==1.12.1+cu111 torchvision==0.9.0+cu111 torchaudio==0.8.0 -f https://download.pytorch.org/whl/torch_stable.html

# %% [markdown]
# ## What is Einops?
# Einops, an abbreviation of Einstein-Inspired Notation for operations is an open-source python framework for writing deep learning code in a new and better way. Einops provides us with new notation & new operations. It is  a flexible and powerful tool to ensure code readability and reliability with minimalist yet powerful API.
#
# Supports numpy, pytorch, tensorflow, jax, and others.
#
# Source: https://analyticsindiamag.com/reinventing-deep-learning-operation-via-einops/
# ##Example:
# from einops import rearrange, reduce, repeat
# ### Rearrange elements according to the pattern
# - output_tensor = rearrange(input_tensor, 't b c -> b c t')
#
# ### Combine rearrangement and reduction
# - output_tensor = reduce(input_tensor, 'b c (h h2) (w w2) -> b h w c', 'mean', h2=2, w2=2)
#
# ### Copy along a new axis
# - output_tensor = repeat(input_tensor, 'h w -> h w c', c=3)
#
# ### Example given for einops, but code in other frameworks is almost identical
# ````
# from torch.nn import Sequential, Conv2d, MaxPool2d, Linear, ReLU
# from einops.layers.torch import Rearrange
#
# model = Sequential(
#     Conv2d(3, 6, kernel_size=5),
#     MaxPool2d(kernel_size=2),
#     Conv2d(6, 16, kernel_size=5),
#     MaxPool2d(kernel_size=2),
#     # flattening
#     Rearrange('b c h w -> b (c h w)'),
#     Linear(16*5*5, 120),
#     ReLU(),
#     Linear(120, 10),
# )
# ````

# %% [markdown]
# CoAtNet src code

# %%
import torch
import torch.nn as nn

from einops import rearrange
from einops.layers.torch import Rearrange

# 	nn.Conv2d : Applies a 2D convolution over an input signal composed of several input planes.

def conv_3x3_bn(inp, oup, image_size, downsample=False):
    stride = 1 if downsample == False else 2
    return nn.Sequential(                               # build neural networks 
        nn.Conv2d(inp, oup, 3, stride, 1, bias=False),  # slide a matrix or filter over 2D data
        #Channel - The colors(?) that transmit the actual information to the receiver. Usually RGB. The colors in an image are created by a mix of Red, Green, and Blue.
        #inp = number of channels in the input image.
        #oup = number of channels produced by the convolution
        #3 = kernel size (3x3 in this case). Kernel is the filter used to extract the features from the images. The matrix that slides over the 2D data. (In 3D, a filter is a collection of kernels)
        #stride = how many pixels the kernel will shift over the image.
        #bias - is like the b parameter in y = mx + b -- Helps model fit the training set properly
        nn.BatchNorm2d(oup),  # Applies Batch Normalization over a 4D input (a mini-batch of 2D inputs with additional channel dimension) 
        # Batch normalization normalizes the activations of the network between layers in batches so that the batches have a mean of 0 and a variance of 1
        nn.GELU() # The Gaussian Error Linear Unit is an activation function.
        # The GELU activation function is xΦ(x) 
        # GELU consistently achieves the lowest test error rate,
        # posing as a promising alternative to ReLU and ELU for a neural network’s activation function.
    )


class PreNorm(nn.Module):
    def __init__(self, dim, fn, norm):
        super().__init__()    # initializes the parent class object into the child class
        # __init__(): allows the class to initialize the attributes of the class
        # super(): function allows us to avoid using the base class name explicitly.
        self.norm = norm(dim)
        # self represents the instance of the class. By using the “self”  we can access the attributes and methods of the class in python. It binds the attributes with the given arguments.
        # norm is what is generally used to evaluate the error of a model
        # norm returns the matrix norm or vector norm of a given tensor
        # dim – Specifies which dimension or dimensions of input to calculate the norm across. 
        # If dim is None, the norm will be calculated across all dimensions of input. 
        # If the norm type indicated by p does not support the specified number of dimensions, an error will occur.
        self.fn = fn

    def forward(self, x, **kwargs):
        return self.fn(self.norm(x), **kwargs)
        #**kwargs allow to pass multiple arguments or keyword arguments to a function. 


# SE Blocks - the Squeeze-Excite process:a modular implementation that can be easily implemented to most Deep CNNs.
# The main idea of an SE Block is: Assign each channel of a feature map a different weightage (excitation) based on how important each channel is (squeeze).
# crucial to the gains in performance
class SE(nn.Module):
    def __init__(self, inp, oup, expansion=0.25):
        super().__init__()
        self.avg_pool = nn.AdaptiveAvgPool2d(1)                 #Sets the output size of the pooling layer to 1x1
        self.fc = nn.Sequential(
            nn.Linear(oup, int(inp * expansion), bias=False),   #applies a linear transformation
            nn.GELU(),        #applies the Gaussian Error Linear Units function
            nn.Linear(int(inp * expansion), oup, bias=False),
            nn.Sigmoid()      # An activation function that takes a value and turns it into a value between 0 and 1 to predict probabilities.
        )

    def forward(self, x):               # define the flow of forward process 
        b, c, _, _ = x.size()
        y = self.avg_pool(x).view(b, c) # Squeeze - perform Global Average Pooling
        y = self.fc(y).view(b, c, 1, 1)
        return x * y


class FeedForward(nn.Module):
    def __init__(self, dim, hidden_dim, dropout=0.):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(dim, hidden_dim), #applies a linear transformation
            nn.GELU(),       #applies the Gaussian Error Linear Units function
            nn.Dropout(dropout),  # takes in the dropout rate
            # to Prevent Neural Networks from Overfitting because it increase accuracy
            nn.Linear(hidden_dim, dim),   #applies a linear transformation
            nn.Dropout(dropout) # takes in the dropout rate
        )
    # define the flow of forward process 
    def forward(self, x):             # x in the forward() method is the input vector.
        return self.net(x)

# A MBConv is a Inverted Linear BottleNeck layer with Depth-Wise Separable Convolution.
class MBConv(nn.Module):
    def __init__(self, inp, oup, image_size, downsample=False, expansion=4):
        super().__init__()
        self.downsample = downsample    # reducing the sampling rate of a signal.
        # A reduction of the feature maps sizes(downsampling) 
        # as we move through the network enables the possibility of reducing the spatial resolution of the feature map.
        stride = 1 if self.downsample == False else 2
        # Stride is a parameter of the neural network's filter that modifies the amount of movement over the image or video. For example, if a neural network's stride is set to 1, the filter will move one pixel, or unit, at a time.
        #If stride = 2, the filter will move two pixels.
        hidden_dim = int(inp * expansion)   # Number of hidden layers self.
        # The hidden dimension is basically the number of nodes in each layer (like in the Multilayer Perceptron for example) 
        # The embedding size tells the size of the feature vector (the model uses embedded words as input)

        if self.downsample:
            self.pool = nn.MaxPool2d(3, 2, 1)   # Applies a 2D max pooling over an input signal composed of several input planes.
            # kernel_size=3, padding=2, dilation=1
            # kernel_size – the size of the window to take a max over
            # stride – the stride of the window. Default value is kernel_size
            # padding – implicit zero padding to be added on both sides
            # dilation – a parameter that controls the stride of elements in the window
            self.proj = nn.Conv2d(inp, oup, 1, 1, 0, bias=False)
            # slide a matrix or filter over 2D data

        if expansion == 1:
            self.conv = nn.Sequential(
                # dw
                nn.Conv2d(hidden_dim, hidden_dim, 3, stride,    # build neural networks that slide a matrix or filter over 2D data
                          1, groups=hidden_dim, bias=False),
                nn.BatchNorm2d(hidden_dim),                     # Applies Batch Normalization over a 4D input (a mini-batch of 2D inputs with additional channel dimension) 
                nn.GELU(),                                      #applies the Gaussian Error Linear Units function
                # pw-linear
                nn.Conv2d(hidden_dim, oup, 1, 1, 0, bias=False), # build neural networks that slide a matrix or filter over 2D data
                nn.BatchNorm2d(oup),                             # Applies Batch Normalization over a 4D input (a mini-batch of 2D inputs with additional channel dimension) 
            )
        else:
            self.conv = nn.Sequential(
                # pw
                # down-sample in the first conv
                nn.Conv2d(inp, hidden_dim, 1, stride, 0, bias=False),    # build neural networks that slide a matrix or filter over 2D data
                nn.BatchNorm2d(hidden_dim),                              # Applies Batch Normalization over a 4D input (a mini-batch of 2D inputs with additional channel dimension)
                nn.GELU(),
                # dw
                nn.Conv2d(hidden_dim, hidden_dim, 3, 1, 1,
                          groups=hidden_dim, bias=False),                # build neural networks that slide a matrix or filter over 2D data
                nn.BatchNorm2d(hidden_dim),                              # Applies Batch Normalization over a 4D input (a mini-batch of 2D inputs with additional channel dimension)
                nn.GELU(),                                               #applies the Gaussian Error Linear Units function
                SE(inp, hidden_dim),
                # pw-linear
                nn.Conv2d(hidden_dim, oup, 1, 1, 0, bias=False),         # build neural networks that slide a matrix or filter over 2D data
                nn.BatchNorm2d(oup),                                     # Applies Batch Normalization over a 4D input (a mini-batch of 2D inputs with additional channel dimension)
            ) 
        
        self.conv = PreNorm(inp, self.conv, nn.BatchNorm2d)

    def forward(self, x):           # define the flow of forward process
        if self.downsample:
            return self.proj(self.pool(x)) + self.conv(x)
        else:
            return x + self.conv(x)

# multihead attention: The goal is to take an average over the features of multiple elements.
# Allows the model to jointly attend to information from different representation subspaces
# Attention models (or mechanisms) are neural network input processing strategies 
# that allow the network to focus on specific parts of a complicated input one by one until the entire dataset is categorized
class Attention(nn.Module):
    def __init__(self, inp, oup, image_size, heads=8, dim_head=32, dropout=0.):
      # dim_head – Total dimension of the model.
      # heads – Number of parallel attention heads. Note that dim_head will be split across num_heads (i.e. each head will have dimension dim_head // heads).
      # dropout – Dropout probability on attn_output_weights. Default: 0.0 (no dropout).
        super().__init__()
        inner_dim = dim_head * heads
        project_out = not (heads == 1 and dim_head == inp)

        self.ih, self.iw = image_size

        self.heads = heads
        self.scale = dim_head ** -0.5

        # parameter table of relative position bias
        self.relative_bias_table = nn.Parameter(
            torch.zeros((2 * self.ih - 1) * (2 * self.iw - 1), heads))

        coords = torch.meshgrid((torch.arange(self.ih), torch.arange(self.iw)))
        coords = torch.flatten(torch.stack(coords), 1)
        relative_coords = coords[:, :, None] - coords[:, None, :]

        relative_coords[0] += self.ih - 1
        relative_coords[1] += self.iw - 1
        relative_coords[0] *= 2 * self.iw - 1
        relative_coords = rearrange(relative_coords, 'c h w -> h w c')
        relative_index = relative_coords.sum(-1).flatten().unsqueeze(1)
        self.register_buffer("relative_index", relative_index)

        self.attend = nn.Softmax(dim=-1)
        self.to_qkv = nn.Linear(inp, inner_dim * 3, bias=False)

        self.to_out = nn.Sequential(
            nn.Linear(inner_dim, oup),
            nn.Dropout(dropout)
        ) if project_out else nn.Identity()

    def forward(self, x):
        qkv = self.to_qkv(x).chunk(3, dim=-1)
        q, k, v = map(lambda t: rearrange(
            t, 'b n (h d) -> b h n d', h=self.heads), qkv)

        dots = torch.matmul(q, k.transpose(-1, -2)) * self.scale

        # Use "gather" for more efficiency on GPUs
        relative_bias = self.relative_bias_table.gather(
            0, self.relative_index.repeat(1, self.heads))
        relative_bias = rearrange(
            relative_bias, '(h w) c -> 1 c h w', h=self.ih*self.iw, w=self.ih*self.iw)
        dots = dots + relative_bias

        attn = self.attend(dots)
        out = torch.matmul(attn, v)
        out = rearrange(out, 'b h n d -> b n (h d)')
        out = self.to_out(out)
        return out

# Transformer architecture implements an encoder-decoder structure without recurrence and convolutions in order to generate an output.
# A transformer is a deep learning model that adopts the mechanism of self-attention, differentially weighting the significance of each part of the input data.
class Transformer(nn.Module):
    def __init__(self, inp, oup, image_size, heads=8, dim_head=32, downsample=False, dropout=0.):
        super().__init__()
        hidden_dim = int(inp * 4)

        self.ih, self.iw = image_size
        self.downsample = downsample

        if self.downsample:
            self.pool1 = nn.MaxPool2d(3, 2, 1)
            self.pool2 = nn.MaxPool2d(3, 2, 1)
            self.proj = nn.Conv2d(inp, oup, 1, 1, 0, bias=False)

        self.attn = Attention(inp, oup, image_size, heads, dim_head, dropout)     # attention technique
        #inp = number of channels in the input image.
        #oup = number of channels produced by the convolution
        #dim = dimension per head
        self.ff = FeedForward(oup, hidden_dim, dropout)
        # feed-forward neural networks: used in practice to transform the attention vectors into a digestible form by the next encoder/decoder block

        self.attn = nn.Sequential(
            Rearrange('b c ih iw -> b (ih iw) c'),
            PreNorm(inp, self.attn, nn.LayerNorm),
            Rearrange('b (ih iw) c -> b c ih iw', ih=self.ih, iw=self.iw)
        )

        self.ff = nn.Sequential(
            Rearrange('b c ih iw -> b (ih iw) c'),  # # concatenated images along horizontal axis
            # einops.rearrange is a reader-friendly smart element reordering for multidimensional tensors. 
            # This operation includes functionality of transpose (axes permutation), reshape (view), squeeze, unsqueeze, stack, concatenate and other operations.
            PreNorm(oup, self.ff, nn.LayerNorm),
            # nn.LayerNorm - Applies Layer Normalization over a mini-batch of inputs as described in the paper Layer Normalization
            Rearrange('b (ih iw) c -> b c ih iw', ih=self.ih, iw=self.iw)   # space-to-depth operation
            # ih, iw = image_size
        )

    def forward(self, x):
        if self.downsample:
            x = self.proj(self.pool1(x)) + self.attn(self.pool2(x))
        else:
            x = x + self.attn(x)
        x = x + self.ff(x)
        return x


class CoAtNet(nn.Module):
    def __init__(self, image_size, in_channels, num_blocks, channels, num_classes=1000, block_types=['C', 'C', 'T', 'T']):
        super().__init__()
        ih, iw = image_size
        block = {'C': MBConv, 'T': Transformer}

        self.s0 = self._make_layer(
            conv_3x3_bn, in_channels, channels[0], num_blocks[0], (ih // 2, iw // 2))
        self.s1 = self._make_layer(
            block[block_types[0]], channels[0], channels[1], num_blocks[1], (ih // 4, iw // 4))
        self.s2 = self._make_layer(
            block[block_types[1]], channels[1], channels[2], num_blocks[2], (ih // 8, iw // 8))
        self.s3 = self._make_layer(
            block[block_types[2]], channels[2], channels[3], num_blocks[3], (ih // 16, iw // 16))
        self.s4 = self._make_layer(
            block[block_types[3]], channels[3], channels[4], num_blocks[4], (ih // 32, iw // 32))

        self.pool = nn.AvgPool2d(ih // 32, 1)
        self.fc = nn.Linear(channels[-1], num_classes, bias=False)

    def forward(self, x):
        x = self.s0(x)
        x = self.s1(x)
        x = self.s2(x)
        x = self.s3(x)
        x = self.s4(x)

        x = self.pool(x).view(-1, x.shape[1])
        x = self.fc(x)
        return x

    def _make_layer(self, block, inp, oup, depth, image_size):
        layers = nn.ModuleList([])
        for i in range(depth):
            if i == 0:
                layers.append(block(inp, oup, image_size, downsample=True))
            else:
                layers.append(block(oup, oup, image_size))
        return nn.Sequential(*layers)


def coatnet_0():
    num_blocks = [2, 2, 3, 5, 2]            # L
    channels = [64, 96, 192, 384, 768]      # D
    return CoAtNet((224, 224), 3, num_blocks, channels, num_classes=1000)


def coatnet_1():
    num_blocks = [2, 2, 6, 14, 2]           # L
    channels = [64, 96, 192, 384, 768]      # D
    return CoAtNet((224, 224), 3, num_blocks, channels, num_classes=1000)


def coatnet_2():
    num_blocks = [2, 2, 6, 14, 2]           # L
    channels = [128, 128, 256, 512, 1026]   # D
    return CoAtNet((224, 224), 3, num_blocks, channels, num_classes=1000)


def coatnet_3():
    num_blocks = [2, 2, 6, 14, 2]           # L
    channels = [192, 192, 384, 768, 1536]   # D
    return CoAtNet((224, 224), 3, num_blocks, channels, num_classes=1000)


def coatnet_4():
    num_blocks = [2, 2, 12, 28, 2]          # L
    channels = [192, 192, 384, 768, 1536]   # D
    return CoAtNet((224, 224), 3, num_blocks, channels, num_classes=1000)



#PyTorch doesn't have a function to calculate the total number of parameters as Keras does, 
#but it's possible to sum the number of elements for every parameter group
#trainable parameters
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)


if __name__ == '__main__':
    img = torch.randn(1, 3, 224, 224)

    net = coatnet_0()
    out = net(img)
    print(out.shape, count_parameters(net))

    net = coatnet_1()
    out = net(img)
    print(out.shape, count_parameters(net))

    net = coatnet_2()
    out = net(img)
    print(out.shape, count_parameters(net))

    net = coatnet_3()
    out = net(img)
    print(out.shape, count_parameters(net))

    net = coatnet_4()
    out = net(img)
    print(out.shape, count_parameters(net))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# torch.Size([1, 1000]) 17789624
# torch.Size([1, 1000]) 33170624
# torch.Size([1, 1000]) 55767564
# torch.Size([1, 1000]) 117724480
# torch.Size([1, 1000]) 203960368

# %% [markdown]
# Pytorch

# %% [markdown]
# Pytorch is an open source machine learning framework that accelerates the path from research prototyping to production deployment.

# %% [markdown]
# - Pytorch.nn: The nn package defines a set of Modules, which you can think of as a neural network layer that has produces output from input and may have some trainable weights.
#   - nn documents: https://pytorch.org/docs/stable/nn.html
#   - Container
#     - nn.Module: Base class for all neural network modules.
#       - Example:
#             class Model(nn.Module):
#               def __init__(self):
#               super().__init__()
#               self.conv1 = nn.Conv2d(1, 20, 5)
#               self.conv2 = nn.Conv2d(20, 20, 5)
#       - Modules can also contain other Modules, allowing to nest them in a tree structure:
#             module (Module) – child module to be added to the module
#     - nn.Sequential: A sequential container.
#       - Class torch.nn.Sequential(*args)
#       - Modules will be added to it in the order they are passed in the constructor. It accepts any input and forwards it to the first module it contains. It then “chains” outputs to inputs sequentially for each subsequent module, finally returning the output of the last module.
#       - Example:
#             model = nn.Sequential(
#                       nn.Conv2d(1,20,5),
#                       nn.ReLU(),
#                       nn.Conv2d(20,64,5),
#                       nn.ReLU()
#                     )
#       -> Run `model`: input will first be passed to `Conv2d(1,20,5)` -> output of `Conv2d(1,20,5)` is used as input to the first `ReLU` -> output of the first `ReLU` becomes input for `Conv2d(20,64,5)` -> output of `Conv2d(20,64,5)` is used as input to the second `ReLU`.
#   - Convolution Layers (https://github.com/vdumoulin/conv_arithmetic/blob/master/README.md)
#     - nn.Conv2d: Applies a 2D convolution over an input signal composed of several input planes.
#     - Constructor: torch.nn.Conv2d(in_channels, out_channels, kernel_size, stride=1, padding=0, dilation=1, groups=1, bias=True, padding_mode='zeros', device=None, dtype=None)
#       - stride: stride for the cross-correlation, a single number or a tuple.
#       - padding: amount of padding applied to the input.
#       - dilation: spacing between the kernel points.
#       - groups: connections between inputs and outputs.
#         - 1: all inputs are convolved to all outputs.
#         - 2: the operation becomes equivalent to having two conv layers side by side, each seeing half the input channels and producing half the output channels, and both subsequently concatenated.
#         - in_channels: each input channel is convolved with its own set of filters
#   - Non-linear Activations
#     - nn.ReLU: Applies the rectified linear unit function element-wise:
#             ReLU(x) = (x)+ = max(0,x)
#       - Constructor: CLASStorch.nn.ReLU(inplace=False)
#         - inplace – can optionally do the operation in-place. Default: False
#   - Normalization Layers
#     - nn.BatchNorm2d: Applies Batch Normalization over a 4D input (a mini-batch of 2D inputs with additional channel dimension).
#     - Constructor: CLASS torch.nn.BatchNorm2d(num_features, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True, device=None, dtype=None)
#       - num_features – CC from an expected input of size (N, C, H, W)(N,C,H,W)
#       - eps – a value added to the denominator for numerical stability.
#         - Default: 1e-5
#       - momentum – the value used for the running_mean and running_var computation.
#         - None for cumulative moving average
#         - Default: 0.1
#       - affine – a boolean value.
#         - True: this module has learnable affine parameters. Default: True
#       - track_running_stats – a boolean value. Default: True
#         - True: this module tracks the running mean and variance,
#         - False: this module does not track such statistics
#     - read: https://arxiv.org/abs/1502.03167

# %% [markdown]
# - torch.randn (*size, *, out=None, dtype=None, layout=torch.strided, device=None, requires_grad=False)
#   - Returns a tensor filled with random numbers from a normal distribution with mean 0 and variance 1 (standard normal distribution).
#   - Parameters
#     - size - sequence of integers defining the size of the output tensor. Can be a variable number of arguments or a collection like a list or tuple.
#     - out (Tensor, optional) – the output tensor.
#     - dtype (torch.dtype, optional) – the desired data type of returned tensor.
#       - Default: None - uses a global default.
#     - layout (torch.layout, optional) – the desired layout of returned Tensor.
#       - Default: torch.strided.
#     - device (torch.device, optional)
#       - the desired device of returned tensor.
#       - Default: None - uses the current device for the default tensor type. device will be the CPU for CPU tensor types and the current CUDA device for CUDA tensor types.
#     - requires_grad (bool, optional) – If autograd should record operations on the returned tensor. Default: False.

# %%
import torch
x=torch.randn(1,3,224,224)
print(x)
x.shape
# Out:
# tensor([[[[-1.0491, -1.1514,  1.9629,  ..., -2.7509,  0.1268,  0.3637],
#           [-0.4312, -0.1322,  0.9069,  ..., -0.0073,  0.9862,  0.2295],
#           [ 0.3014, -0.3451, -0.1001,  ...,  0.4791, -0.5068,  0.9185],
#           ...,
#           [-1.6083, -0.8264, -0.6177,  ..., -1.4355,  2.2524, -0.5714],
#           [-1.0237, -0.1278,  0.4988,  ..., -0.0532,  1.1298,  0.1337],
#           [-0.6100, -1.1884, -1.7726,  ...,  0.5237,  1.4916,  0.5178]],
#
#          [[ 2.3873, -1.7982,  1.0560,  ...,  0.5562,  2.0897,  1.5657],
#           [ 2.1143, -0.0450, -0.0739,  ..., -0.2172, -0.8743, -1.0608],
#           [ 0.3300, -1.8683, -0.4806,  ..., -1.0062,  1.0681,  0.2280],
#           ...,
#           [ 1.9076,  1.4221, -0.3436,  ...,  0.6943,  0.6818,  0.4254],
#           [-0.2510,  0.3901, -0.4770,  ...,  0.0974, -0.4882,  0.3515],
#           [ 0.8329, -1.2250,  0.1495,  ...,  0.8054,  1.0910,  0.4240]],
#
#          [[ 1.6711,  0.2248, -1.4143,  ...,  0.8116,  0.0670,  1.5383],
#           [ 2.4841,  1.4102,  1.3154,  ..., -0.8535, -0.1311,  0.0418],
#           [ 0.7304,  1.0577, -1.5749,  ..., -1.2232,  0.3631,  0.6508],
#           ...,
#           [ 1.4268,  0.6378, -1.1667,  ...,  0.0802,  0.4169, -0.5231],
#           [ 1.1148,  1.1981, -1.5006,  ..., -1.1336, -1.1128,  1.2870],
#           [-1.1603,  1.9897,  0.2871,  ...,  0.3213,  0.0982, -1.3233]]]])
# torch.Size([1, 3, 224, 224])

# %%
import torch
x=torch.randn(2,4)
print(x)
x.shape
# Out:
# tensor([[ 0.6246, -0.2541, -0.1754, -2.4561],
#         [-0.4629,  1.1067, -0.4762, -0.8079]])
# torch.Size([2, 4])

# %%
import torch
x=torch.randn(2,4,5)
print(x)
x.shape
# Out:
# tensor([[[ 0.3221, -1.0784, -0.5947,  0.0802, -0.1848],
#          [-1.1483, -1.0827,  1.4569,  0.2496,  1.9261],
#          [-0.3847,  0.2568, -0.3226, -1.2158, -0.5063],
#          [-0.3135, -0.0692,  0.5999,  0.3979, -0.1399]],
#
#         [[-0.4653,  0.7445,  1.4121,  0.5809,  1.8873],
#          [ 1.7006, -1.2066, -0.3792, -0.5553,  0.1024],
#          [ 0.0962,  0.2177, -1.3693,  0.9639,  1.6745],
#          [ 0.7280,  0.1192, -0.5150, -0.2192,  1.0257]]])
# torch.Size([2, 4, 5])

# %% [markdown]
# ```
# def conv_3x3_bn(inp, oup, image_size, downsample=False): stride = 1 if downsample == False else 2
#     return nn.Sequential(
#         nn.Conv2d(inp, oup, 3, stride, 1, bias=False),
#         nn.BatchNorm2d(oup),
#         nn.GELU()
#     )
# ```
#
#
#
# **nn.Sequential()**
#
# Class that allows us to build neural networks on the fly without having to define an explicit class.
#
#   **nn.Conv2d(inp, oup, 3, stride, 1, bias=False)**
#
#   2D Convolution - We slide a matrix or filter over 2D data (an image turned into a grid of numbers) and perform element-wise multiplication with the data, then sum up the multiplication result to produce an output. We move the filter in strides until we get the final output matrix of the 2D convolution operation.
#
#   Channel - The colors(?) that transmit the actual information to the receiver. Usually RGB. The colors in an image are created by a mix of Red, Green, and Blue.
#
#   inp = number of channels in the input image.
#
#   oup = number of channels produced by the convolution
#
#   3 = kernel size (3x3 in this case). Kernel is the filter used to extract the features from the images. The matrix that slides over the 2D data. (In 3D, a filter is a collection of kernels)
#
#   stride = how many pixels the kernel will shift over the image.
#
#   bias - is like the *b* parameter in *y = mx + b* -- Helps model fit the training set properly
#
#   **nn.BatchNorm2d(oup)**
#   is needed to normalize the output so the data will be on the same scale. If one feature is too large, this feature will drown out the smaller feature. During gradient descent, the neural network will have to make a large update to one weight compared to the other weight. It can cause the gradient descent trajectory to oscillate back and forth, thus taking more steps to reach the minimum.
#
#   **nn.GELU**
#
#   Gaussian Error Linear Units function. An activation function like sigmoid and RELU
#
#
#
# ---
#
# ```
# class SE(nn.Module):
#     def __init__(self, inp, oup, expansion=0.25):
#         super().__init__()
#         self.avg_pool = nn.AdaptiveAvgPool2d(1)
#         self.fc = nn.Sequential(
#             nn.Linear(oup, int(inp * expansion), bias=False),
#             nn.GELU(),
#             nn.Linear(int(inp * expansion), oup, bias=False),
#             nn.Sigmoid()
#         )
# ```
#
# **nn.AdaptiveAvgPool2d(1)**
#
# Sets the output size of the pooling layer to the specified size. (1x1 in this case) The stride and kernel-size are automatically selected to get this output size.
#
# Pooling compresses and generalizes the features in the feature map.
#
# **nn.Linear()**
#
# **nn.Sigmoid()**
#
# An activation function that takes a value and turns it into a value between 0 and 1 to predict probabilities.

# %% [markdown]
# Import libraries

# %%
#os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

# %%
import torch.optim as optim #optimizer, will hold the current state and will update the parameters based on the computed gradients
import torch
import torch.nn as nn #neural network framework
import torch.nn.parallel 
import torch.utils.data
import torch.utils.data.distributed
import torchvision.transforms as transforms #common image transformation
from torch.autograd import Variable #automatic differentiation

# %% [markdown]
# Set global parameters

# %%
modellr = 1e-4
BATCH_SIZE = 16 #the dataset is divided into batches, each of 16 
EPOCHS = 100 #number of times the entire dataset is passed through the neural network
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')#the GPU device that operations will be on

# %% [markdown]
# Data Preprocessing

# %%
#modifying images (resize, convert, normalize)  
transform = transforms.Compose([ #chain the transformation together
    transforms.Resize((224, 224)), #resize image
    transforms.ToTensor(), #convert image to a tensor (matrix)
    transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5]) #normalize with (mean, standard deviation)

])
transform_test = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])
])

# %% [markdown]
# Fetch the data

# %%
# coding:utf8
import os
from PIL import Image
from torch.utils import data
from torchvision import transforms as T
from sklearn.model_selection import train_test_split


Labels = {
     'daisy': 0, 'dandelion': 1, 'rose': 2, 'sunflower': 3, 'tulip':4
}
 
class FlowerData (data.Dataset):
 
    def __init__(self, root, transforms=None, train=True, test=False):
        """
        Main objective: to obtain the addresses of all pictures and divide the data according to training, verification and test
        """
        self.test = test
        self.transforms = transforms
 
        if self.test:
            imgs = [os.path.join(root, img) for img in os.listdir(root)]
            self.imgs = imgs
        else:
            imgs_labels = [os.path.join(root, img) for img in os.listdir(root)]
            imgs = []
            for imglable in imgs_labels:
                for imgname in os.listdir(imglable):
                    imgpath = os.path.join(imglable, imgname)
                    imgs.append(imgpath)
            trainval_files, val_files = train_test_split(imgs, test_size=0.3, random_state=42)
            if train:
                self.imgs = trainval_files
            else:
                self.imgs = val_files
 
    def __getitem__(self, index):
        """
        Returns the data of one picture at a time
        """
        img_path = self.imgs[index]
        img_path=img_path.replace("\\",'/')
        if self.test:
            label = -1
        else:
            labelname = img_path.split('/')[-2]
            label = Labels[labelname]
        data = Image.open(img_path).convert('RGB')
        data = self.transforms(data)
        return data, label
 
    def __len__(self):
        return len(self.imgs)

# %%
# split-data
# !pip install split-folders
import splitfolders
import pathlib
data = "drive/My Drive/195A+BSeniorProjectGroupWorks/Datasets/Flower_Dataset/flowers"
data_splitted = "drive/My Drive/195A+BSeniorProjectGroupWorks/Datasets/Flower_Dataset/flowers_train_test_set"
# splitfolders.ratio(data, data_splitted, seed=1337, ratio=(.8, .1, .1))
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: split-folders in /usr/local/lib/python3.7/dist-packages (0.5.1)

# %%
# Read data
# Suggestion: automates image look-up/download from the web
dataset_train = FlowerData(pathlib.Path(data_splitted)/"train", transforms=transform, train=True)
dataset_test = FlowerData(pathlib.Path(data_splitted)/"val", transforms=transform_test, train=False)

# %%
# Import data
train_loader = torch.utils.data.DataLoader(dataset_train, batch_size=BATCH_SIZE, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset_test, batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# Set model

# %%
# Instantiate the model and move to the GPU
criterion = nn.CrossEntropyLoss()

model_ft = coatnet_2()
num_ftrs = model_ft.fc.in_features
model_ft.fc = nn.Linear(num_ftrs, 200) #change the 2nd arg according to the number of Labels
#TODO: look into why changing this arg fixes the error
model_ft.to(DEVICE)#move the model to GPU
# Choose the simple and violent Adam optimizer to reduce the learning rate
optimizer = optim.Adam(model_ft.parameters(), lr=modellr)
cosine_schedule = optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer,T_max=20,eta_min=1e-9)

# %%
# Define training process

def train(model, device, train_loader, optimizer, epoch):
    model.train()#set the mode to train mode, not actually training using this function
    sum_loss = 0
    total_num = len(train_loader.dataset)
    print(total_num, len(train_loader))
    for batch_idx, (data, target) in enumerate(train_loader):#enumrate is a counter for the loop
        data, target = Variable(data).to(device), Variable(target).to(device)#send data
        output = model(data)
        loss = criterion(output, target)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        print_loss = loss.data.item()
        sum_loss += print_loss
        if (batch_idx + 1) % 10 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, (batch_idx + 1) * len(data), len(train_loader.dataset),
                       100. * (batch_idx + 1) / len(train_loader), loss.item()))
    ave_loss = sum_loss / len(train_loader)
    print('epoch:{},loss:{}'.format(epoch, ave_loss))


# Verification process
def val(model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    total_num = len(test_loader.dataset)
    print(total_num, len(test_loader))
    with torch.no_grad():
        for data, target in test_loader:
            data, target = Variable(data).to(device), Variable(target).to(device)
            output = model(data)
            loss = criterion(output, target)
            _, pred = torch.max(output.data, 1)
            correct += torch.sum(pred == target)
            print_loss = loss.data.item()
            test_loss += print_loss
        correct = correct.data.item()
        acc = correct / total_num
        avgloss = test_loss / len(test_loader)
        print('\nVal set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
            avgloss, correct, len(test_loader.dataset), 100 * acc))


# train

for epoch in range(1, EPOCHS + 1):
    train(model_ft, DEVICE, train_loader, optimizer, epoch)
    cosine_schedule.step()
    val(model_ft, DEVICE, test_loader)
# Out:
# 2444 153
# Train Epoch: 1 [160/2444 (7%)]	Loss: 2.161116
# Train Epoch: 1 [320/2444 (13%)]	Loss: 2.990059
# Train Epoch: 1 [480/2444 (20%)]	Loss: 1.835641
# Train Epoch: 1 [640/2444 (26%)]	Loss: 0.934655
# Train Epoch: 1 [800/2444 (33%)]	Loss: 1.076860
# Train Epoch: 1 [960/2444 (39%)]	Loss: 1.455194
# Train Epoch: 1 [1120/2444 (46%)]	Loss: 1.296149
# Train Epoch: 1 [1280/2444 (52%)]	Loss: 1.278415
# Train Epoch: 1 [1440/2444 (59%)]	Loss: 1.118919
# Train Epoch: 1 [1600/2444 (65%)]	Loss: 0.991024
# Train Epoch: 1 [1760/2444 (72%)]	Loss: 0.875259
# Train Epoch: 1 [1920/2444 (78%)]	Loss: 2.367704
# Train Epoch: 1 [2080/2444 (85%)]	Loss: 1.307439
# Train Epoch: 1 [2240/2444 (92%)]	Loss: 0.799721
# Train Epoch: 1 [2400/2444 (98%)]	Loss: 0.923970
# epoch:1,loss:1.4901109532593122
# 131 9
#
# Val set: Average loss: 1.1065, Accuracy: 82/131 (63%)
#
# 2444 153
# Train Epoch: 2 [160/2444 (7%)]	Loss: 1.451248
# Train Epoch: 2 [320/2444 (13%)]	Loss: 1.037537
# Train Epoch: 2 [480/2444 (20%)]	Loss: 1.475525
# Train Epoch: 2 [640/2444 (26%)]	Loss: 1.096515
# Train Epoch: 2 [800/2444 (33%)]	Loss: 0.625285
# Train Epoch: 2 [960/2444 (39%)]	Loss: 1.616080
# Train Epoch: 2 [1120/2444 (46%)]	Loss: 0.777996
# Train Epoch: 2 [1280/2444 (52%)]	Loss: 1.318106
# Train Epoch: 2 [1440/2444 (59%)]	Loss: 1.301664
# Train Epoch: 2 [1600/2444 (65%)]	Loss: 1.501765
# Train Epoch: 2 [1760/2444 (72%)]	Loss: 1.002032
# Train Epoch: 2 [1920/2444 (78%)]	Loss: 0.673806
# Train Epoch: 2 [2080/2444 (85%)]	Loss: 1.040400
# Train Epoch: 2 [2240/2444 (92%)]	Loss: 0.856411
# Train Epoch: 2 [2400/2444 (98%)]	Loss: 0.602620
# epoch:2,loss:1.0149656279024735
# 131 9
#
# Val set: Average loss: 1.0504, Accuracy: 84/131 (64%)
#
# 2444 153
# Train Epoch: 3 [160/2444 (7%)]	Loss: 0.678654
# Train Epoch: 3 [320/2444 (13%)]	Loss: 1.087470
# Train Epoch: 3 [480/2444 (20%)]	Loss: 0.683194
# Train Epoch: 3 [640/2444 (26%)]	Loss: 0.693218
# Train Epoch: 3 [800/2444 (33%)]	Loss: 1.293680
# Train Epoch: 3 [960/2444 (39%)]	Loss: 0.377366
# Train Epoch: 3 [1120/2444 (46%)]	Loss: 1.026299
# Train Epoch: 3 [1280/2444 (52%)]	Loss: 0.942024
# Train Epoch: 3 [1440/2444 (59%)]	Loss: 0.869964
# Train Epoch: 3 [1600/2444 (65%)]	Loss: 0.566597
# Train Epoch: 3 [1760/2444 (72%)]	Loss: 1.204726
# Train Epoch: 3 [1920/2444 (78%)]	Loss: 0.762237
# Train Epoch: 3 [2080/2444 (85%)]	Loss: 0.631474
# Train Epoch: 3 [2240/2444 (92%)]	Loss: 0.878950
# Train Epoch: 3 [2400/2444 (98%)]	Loss: 0.713572
# epoch:3,loss:0.8322091893432966
# 131 9
#
# Val set: Average loss: 1.0246, Accuracy: 86/131 (66%)
#
# 2444 153
# Train Epoch: 4 [160/2444 (7%)]	Loss: 0.710293
# Train Epoch: 4 [320/2444 (13%)]	Loss: 0.563983
# Train Epoch: 4 [480/2444 (20%)]	Loss: 0.676293
# Train Epoch: 4 [640/2444 (26%)]	Loss: 0.538611
# Train Epoch: 4 [800/2444 (33%)]	Loss: 0.466310
# Train Epoch: 4 [960/2444 (39%)]	Loss: 0.540910
# Train Epoch: 4 [1120/2444 (46%)]	Loss: 0.431044
# Train Epoch: 4 [1280/2444 (52%)]	Loss: 0.780089
# Train Epoch: 4 [1440/2444 (59%)]	Loss: 0.771740
# Train Epoch: 4 [1600/2444 (65%)]	Loss: 0.768409
# Train Epoch: 4 [1760/2444 (72%)]	Loss: 0.333622
# Train Epoch: 4 [1920/2444 (78%)]	Loss: 0.923586
# Train Epoch: 4 [2080/2444 (85%)]	Loss: 0.660087
# Train Epoch: 4 [2240/2444 (92%)]	Loss: 0.605769
# Train Epoch: 4 [2400/2444 (98%)]	Loss: 0.529855
# epoch:4,loss:0.6972191624976452
# 131 9
#
# Val set: Average loss: 1.1274, Accuracy: 87/131 (66%)
#
# 2444 153
# Train Epoch: 5 [160/2444 (7%)]	Loss: 0.634617
# Train Epoch: 5 [320/2444 (13%)]	Loss: 1.008802
# Train Epoch: 5 [480/2444 (20%)]	Loss: 0.226093
# Train Epoch: 5 [640/2444 (26%)]	Loss: 0.570562
# Train Epoch: 5 [800/2444 (33%)]	Loss: 0.576664
# Train Epoch: 5 [960/2444 (39%)]	Loss: 0.389924
# Train Epoch: 5 [1120/2444 (46%)]	Loss: 0.486204
# Train Epoch: 5 [1280/2444 (52%)]	Loss: 1.023945
# Train Epoch: 5 [1440/2444 (59%)]	Loss: 0.519750
# Train Epoch: 5 [1600/2444 (65%)]	Loss: 0.386861
# Train Epoch: 5 [1760/2444 (72%)]	Loss: 0.747113
# Train Epoch: 5 [1920/2444 (78%)]	Loss: 0.493012
# Train Epoch: 5 [2080/2444 (85%)]	Loss: 1.110799
# Train Epoch: 5 [2240/2444 (92%)]	Loss: 0.553388
# Train Epoch: 5 [2400/2444 (98%)]	Loss: 0.488816
# epoch:5,loss:0.6152149098955728
# 131 9
#
# Val set: Average loss: 0.8590, Accuracy: 96/131 (73%)
#
# 2444 153
# Train Epoch: 6 [160/2444 (7%)]	Loss: 0.708702
# Train Epoch: 6 [320/2444 (13%)]	Loss: 0.607839
# Train Epoch: 6 [480/2444 (20%)]	Loss: 0.683698
# Train Epoch: 6 [640/2444 (26%)]	Loss: 0.332500
# Train Epoch: 6 [800/2444 (33%)]	Loss: 0.556996
# Train Epoch: 6 [960/2444 (39%)]	Loss: 0.847283
# Train Epoch: 6 [1120/2444 (46%)]	Loss: 0.677089
# Train Epoch: 6 [1280/2444 (52%)]	Loss: 0.186350
# Train Epoch: 6 [1440/2444 (59%)]	Loss: 0.555369
# Train Epoch: 6 [1600/2444 (65%)]	Loss: 0.153796
# Train Epoch: 6 [1760/2444 (72%)]	Loss: 0.248804
# Train Epoch: 6 [1920/2444 (78%)]	Loss: 0.187387
# Train Epoch: 6 [2080/2444 (85%)]	Loss: 0.634347
# Train Epoch: 6 [2240/2444 (92%)]	Loss: 0.652851
# Train Epoch: 6 [2400/2444 (98%)]	Loss: 0.452245
# epoch:6,loss:0.5085821570524203
# 131 9
#
# Val set: Average loss: 1.0102, Accuracy: 82/131 (63%)
#
# 2444 153
# Train Epoch: 7 [160/2444 (7%)]	Loss: 0.268381
# Train Epoch: 7 [320/2444 (13%)]	Loss: 0.581902
# Train Epoch: 7 [480/2444 (20%)]	Loss: 0.237288
# Train Epoch: 7 [640/2444 (26%)]	Loss: 0.275374
# Train Epoch: 7 [800/2444 (33%)]	Loss: 0.486097
# Train Epoch: 7 [960/2444 (39%)]	Loss: 0.244378
# Train Epoch: 7 [1120/2444 (46%)]	Loss: 0.173855
# Train Epoch: 7 [1280/2444 (52%)]	Loss: 0.120568
# Train Epoch: 7 [1440/2444 (59%)]	Loss: 0.658262
# Train Epoch: 7 [1600/2444 (65%)]	Loss: 0.298825
# Train Epoch: 7 [1760/2444 (72%)]	Loss: 0.113724
# Train Epoch: 7 [1920/2444 (78%)]	Loss: 0.620139
# Train Epoch: 7 [2080/2444 (85%)]	Loss: 0.114169
# Train Epoch: 7 [2240/2444 (92%)]	Loss: 0.435287
# Train Epoch: 7 [2400/2444 (98%)]	Loss: 0.115652
# epoch:7,loss:0.3841495427114317
# 131 9
#
# Val set: Average loss: 0.9426, Accuracy: 93/131 (71%)
#
# 2444 153
# Train Epoch: 8 [160/2444 (7%)]	Loss: 0.459592
# Train Epoch: 8 [320/2444 (13%)]	Loss: 0.199243
# Train Epoch: 8 [480/2444 (20%)]	Loss: 0.654631
# Train Epoch: 8 [640/2444 (26%)]	Loss: 0.586074
# Train Epoch: 8 [800/2444 (33%)]	Loss: 0.296670
# Train Epoch: 8 [960/2444 (39%)]	Loss: 0.105396
# Train Epoch: 8 [1120/2444 (46%)]	Loss: 0.152190
# Train Epoch: 8 [1280/2444 (52%)]	Loss: 0.288536
# Train Epoch: 8 [1440/2444 (59%)]	Loss: 0.485452
# Train Epoch: 8 [1600/2444 (65%)]	Loss: 0.218203
# Train Epoch: 8 [1760/2444 (72%)]	Loss: 0.210090
# Train Epoch: 8 [1920/2444 (78%)]	Loss: 0.409136
# Train Epoch: 8 [2080/2444 (85%)]	Loss: 0.176004
# Train Epoch: 8 [2240/2444 (92%)]	Loss: 0.415331
# Train Epoch: 8 [2400/2444 (98%)]	Loss: 0.159025
# epoch:8,loss:0.29872187955024976
# 131 9
#
# Val set: Average loss: 0.9696, Accuracy: 97/131 (74%)
#
# 2444 153
# Train Epoch: 9 [160/2444 (7%)]	Loss: 0.336260
# Train Epoch: 9 [320/2444 (13%)]	Loss: 0.031304
# Train Epoch: 9 [480/2444 (20%)]	Loss: 0.394467
# Train Epoch: 9 [640/2444 (26%)]	Loss: 0.832928
# Train Epoch: 9 [800/2444 (33%)]	Loss: 0.284083
# Train Epoch: 9 [960/2444 (39%)]	Loss: 0.085491
# Train Epoch: 9 [1120/2444 (46%)]	Loss: 0.035905
# Train Epoch: 9 [1280/2444 (52%)]	Loss: 0.104503
# Train Epoch: 9 [1440/2444 (59%)]	Loss: 0.016356
# Train Epoch: 9 [1600/2444 (65%)]	Loss: 0.126078
# Train Epoch: 9 [1760/2444 (72%)]	Loss: 0.076310
# Train Epoch: 9 [1920/2444 (78%)]	Loss: 0.346712
# Train Epoch: 9 [2080/2444 (85%)]	Loss: 0.102232
# Train Epoch: 9 [2240/2444 (92%)]	Loss: 0.026840
# Train Epoch: 9 [2400/2444 (98%)]	Loss: 0.089348
# epoch:9,loss:0.23965800876175267
# 131 9
#
# Val set: Average loss: 1.1303, Accuracy: 99/131 (76%)
#
# 2444 153
# Train Epoch: 10 [160/2444 (7%)]	Loss: 0.062111
# Train Epoch: 10 [320/2444 (13%)]	Loss: 0.146510
# Train Epoch: 10 [480/2444 (20%)]	Loss: 0.060665
# Train Epoch: 10 [640/2444 (26%)]	Loss: 0.026237
# Train Epoch: 10 [800/2444 (33%)]	Loss: 0.387908
# Train Epoch: 10 [960/2444 (39%)]	Loss: 0.102619
# Train Epoch: 10 [1120/2444 (46%)]	Loss: 0.164538
# Train Epoch: 10 [1280/2444 (52%)]	Loss: 0.139184
# Train Epoch: 10 [1440/2444 (59%)]	Loss: 0.041577
# Train Epoch: 10 [1600/2444 (65%)]	Loss: 0.434593
# Train Epoch: 10 [1760/2444 (72%)]	Loss: 0.023963
# Train Epoch: 10 [1920/2444 (78%)]	Loss: 0.063600
# Train Epoch: 10 [2080/2444 (85%)]	Loss: 0.328060
# Train Epoch: 10 [2240/2444 (92%)]	Loss: 0.272957
# Train Epoch: 10 [2400/2444 (98%)]	Loss: 0.186060
# epoch:10,loss:0.16722921072657593
# 131 9
#
# Val set: Average loss: 1.0731, Accuracy: 100/131 (76%)
#
# 2444 153
# Train Epoch: 11 [160/2444 (7%)]	Loss: 0.027321
# Train Epoch: 11 [320/2444 (13%)]	Loss: 0.048083
# Train Epoch: 11 [480/2444 (20%)]	Loss: 0.027873
# Train Epoch: 11 [640/2444 (26%)]	Loss: 0.073270
# Train Epoch: 11 [800/2444 (33%)]	Loss: 0.391908
# Train Epoch: 11 [960/2444 (39%)]	Loss: 0.049351
# Train Epoch: 11 [1120/2444 (46%)]	Loss: 0.098250
# Train Epoch: 11 [1280/2444 (52%)]	Loss: 0.117420
# Train Epoch: 11 [1440/2444 (59%)]	Loss: 0.240429
# Train Epoch: 11 [1600/2444 (65%)]	Loss: 0.036543
# Train Epoch: 11 [1760/2444 (72%)]	Loss: 0.051516
# Train Epoch: 11 [1920/2444 (78%)]	Loss: 0.112654
# Train Epoch: 11 [2080/2444 (85%)]	Loss: 0.016756
# Train Epoch: 11 [2240/2444 (92%)]	Loss: 0.153788
# Train Epoch: 11 [2400/2444 (98%)]	Loss: 0.304065
# epoch:11,loss:0.0983384650967577
# 131 9
#
# Val set: Average loss: 1.1274, Accuracy: 94/131 (72%)
#
# 2444 153
# Train Epoch: 12 [160/2444 (7%)]	Loss: 0.002882
# Train Epoch: 12 [320/2444 (13%)]	Loss: 0.135296
# Train Epoch: 12 [480/2444 (20%)]	Loss: 0.130733
# Train Epoch: 12 [640/2444 (26%)]	Loss: 0.114060
# Train Epoch: 12 [800/2444 (33%)]	Loss: 0.045309
# Train Epoch: 12 [960/2444 (39%)]	Loss: 0.015274
# Train Epoch: 12 [1120/2444 (46%)]	Loss: 0.004616
# Train Epoch: 12 [1280/2444 (52%)]	Loss: 0.063648
# Train Epoch: 12 [1440/2444 (59%)]	Loss: 0.002257
# Train Epoch: 12 [1600/2444 (65%)]	Loss: 0.040098
# Train Epoch: 12 [1760/2444 (72%)]	Loss: 0.009918
# Train Epoch: 12 [1920/2444 (78%)]	Loss: 0.059716
# Train Epoch: 12 [2080/2444 (85%)]	Loss: 0.008325
# Train Epoch: 12 [2240/2444 (92%)]	Loss: 0.105966
# Train Epoch: 12 [2400/2444 (98%)]	Loss: 0.018264
# epoch:12,loss:0.05717793201838979
# 131 9
#
# Val set: Average loss: 1.1578, Accuracy: 97/131 (74%)
#
# 2444 153
# Train Epoch: 13 [160/2444 (7%)]	Loss: 0.023884
# Train Epoch: 13 [320/2444 (13%)]	Loss: 0.162864
# Train Epoch: 13 [480/2444 (20%)]	Loss: 0.035999
# Train Epoch: 13 [640/2444 (26%)]	Loss: 0.004013
# Train Epoch: 13 [800/2444 (33%)]	Loss: 0.115654
# Train Epoch: 13 [960/2444 (39%)]	Loss: 0.012955
# Train Epoch: 13 [1120/2444 (46%)]	Loss: 0.012999
# Train Epoch: 13 [1280/2444 (52%)]	Loss: 0.018456
# Train Epoch: 13 [1440/2444 (59%)]	Loss: 0.066662
# Train Epoch: 13 [1600/2444 (65%)]	Loss: 0.001847
# Train Epoch: 13 [1760/2444 (72%)]	Loss: 0.006672
# Train Epoch: 13 [1920/2444 (78%)]	Loss: 0.200853
# Train Epoch: 13 [2080/2444 (85%)]	Loss: 0.003406
# Train Epoch: 13 [2240/2444 (92%)]	Loss: 0.064840
# Train Epoch: 13 [2400/2444 (98%)]	Loss: 0.037056
# epoch:13,loss:0.047408638104303354
# 131 9
#
# Val set: Average loss: 1.0769, Accuracy: 98/131 (75%)
#
# 2444 153
# Train Epoch: 14 [160/2444 (7%)]	Loss: 0.218689
# Train Epoch: 14 [320/2444 (13%)]	Loss: 0.002230
# Train Epoch: 14 [480/2444 (20%)]	Loss: 0.008017
# Train Epoch: 14 [640/2444 (26%)]	Loss: 0.008092
# Train Epoch: 14 [800/2444 (33%)]	Loss: 0.006405
# Train Epoch: 14 [960/2444 (39%)]	Loss: 0.006846
# Train Epoch: 14 [1120/2444 (46%)]	Loss: 0.000842
# Train Epoch: 14 [1280/2444 (52%)]	Loss: 0.003874
# Train Epoch: 14 [1440/2444 (59%)]	Loss: 0.005021
# Train Epoch: 14 [1600/2444 (65%)]	Loss: 0.003336
# Train Epoch: 14 [1760/2444 (72%)]	Loss: 0.001673
# Train Epoch: 14 [1920/2444 (78%)]	Loss: 0.008614
# Train Epoch: 14 [2080/2444 (85%)]	Loss: 0.003056
# Train Epoch: 14 [2240/2444 (92%)]	Loss: 0.003628
# Train Epoch: 14 [2400/2444 (98%)]	Loss: 0.041599
# epoch:14,loss:0.017353474979328442
# 131 9
#
# Val set: Average loss: 1.2196, Accuracy: 103/131 (79%)
#
# 2444 153
# Train Epoch: 15 [160/2444 (7%)]	Loss: 0.000638
# Train Epoch: 15 [320/2444 (13%)]	Loss: 0.001747
# Train Epoch: 15 [480/2444 (20%)]	Loss: 0.001603
# Train Epoch: 15 [640/2444 (26%)]	Loss: 0.003182
# Train Epoch: 15 [800/2444 (33%)]	Loss: 0.015376
# Train Epoch: 15 [960/2444 (39%)]	Loss: 0.004837
# Train Epoch: 15 [1120/2444 (46%)]	Loss: 0.001829
# Train Epoch: 15 [1280/2444 (52%)]	Loss: 0.006628
# Train Epoch: 15 [1440/2444 (59%)]	Loss: 0.015034
# Train Epoch: 15 [1600/2444 (65%)]	Loss: 0.006239
# Train Epoch: 15 [1760/2444 (72%)]	Loss: 0.001541
# Train Epoch: 15 [1920/2444 (78%)]	Loss: 0.007886
# Train Epoch: 15 [2080/2444 (85%)]	Loss: 0.002274
# Train Epoch: 15 [2240/2444 (92%)]	Loss: 0.008593
# Train Epoch: 15 [2400/2444 (98%)]	Loss: 0.005704
# epoch:15,loss:0.01823580384451715
# 131 9
#
# Val set: Average loss: 1.0206, Accuracy: 101/131 (77%)
#
# 2444 153
# Train Epoch: 16 [160/2444 (7%)]	Loss: 0.010628
# Train Epoch: 16 [320/2444 (13%)]	Loss: 0.003107
# Train Epoch: 16 [480/2444 (20%)]	Loss: 0.006627
# Train Epoch: 16 [640/2444 (26%)]	Loss: 0.002144
# Train Epoch: 16 [800/2444 (33%)]	Loss: 0.001706
# Train Epoch: 16 [960/2444 (39%)]	Loss: 0.001406
# Train Epoch: 16 [1120/2444 (46%)]	Loss: 0.005118
# Train Epoch: 16 [1280/2444 (52%)]	Loss: 0.005616
# Train Epoch: 16 [1440/2444 (59%)]	Loss: 0.008504
# Train Epoch: 16 [1600/2444 (65%)]	Loss: 0.004046
# Train Epoch: 16 [1760/2444 (72%)]	Loss: 0.029313
# Train Epoch: 16 [1920/2444 (78%)]	Loss: 0.000510
# Train Epoch: 16 [2080/2444 (85%)]	Loss: 0.001887
# Train Epoch: 16 [2240/2444 (92%)]	Loss: 0.036325
# Train Epoch: 16 [2400/2444 (98%)]	Loss: 0.001446
# epoch:16,loss:0.007890279578015335
# 131 9
#
# Val set: Average loss: 1.1117, Accuracy: 102/131 (78%)
#
# 2444 153
# Train Epoch: 17 [160/2444 (7%)]	Loss: 0.002039
# Train Epoch: 17 [320/2444 (13%)]	Loss: 0.000821
# Train Epoch: 17 [480/2444 (20%)]	Loss: 0.006270
# Train Epoch: 17 [640/2444 (26%)]	Loss: 0.002474
# Train Epoch: 17 [800/2444 (33%)]	Loss: 0.001505
# Train Epoch: 17 [960/2444 (39%)]	Loss: 0.003426
# Train Epoch: 17 [1120/2444 (46%)]	Loss: 0.000356
# Train Epoch: 17 [1280/2444 (52%)]	Loss: 0.001948
# Train Epoch: 17 [1440/2444 (59%)]	Loss: 0.003646
# Train Epoch: 17 [1600/2444 (65%)]	Loss: 0.011399
# Train Epoch: 17 [1760/2444 (72%)]	Loss: 0.000141
# Train Epoch: 17 [1920/2444 (78%)]	Loss: 0.002293
# Train Epoch: 17 [2080/2444 (85%)]	Loss: 0.000388
# Train Epoch: 17 [2240/2444 (92%)]	Loss: 0.002368
# Train Epoch: 17 [2400/2444 (98%)]	Loss: 0.000843
# epoch:17,loss:0.007157614719509938
# 131 9
#
# Val set: Average loss: 1.1691, Accuracy: 99/131 (76%)
#
# 2444 153
# Train Epoch: 18 [160/2444 (7%)]	Loss: 0.000447
# Train Epoch: 18 [320/2444 (13%)]	Loss: 0.002918
# Train Epoch: 18 [480/2444 (20%)]	Loss: 0.000758
# Train Epoch: 18 [640/2444 (26%)]	Loss: 0.000479
# Train Epoch: 18 [800/2444 (33%)]	Loss: 0.000842
# Train Epoch: 18 [960/2444 (39%)]	Loss: 0.000903
# Train Epoch: 18 [1120/2444 (46%)]	Loss: 0.001498
# Train Epoch: 18 [1280/2444 (52%)]	Loss: 0.001647
# Train Epoch: 18 [1440/2444 (59%)]	Loss: 0.001000
# Train Epoch: 18 [1600/2444 (65%)]	Loss: 0.000299
# Train Epoch: 18 [1760/2444 (72%)]	Loss: 0.002536
# Train Epoch: 18 [1920/2444 (78%)]	Loss: 0.016820
# Train Epoch: 18 [2080/2444 (85%)]	Loss: 0.032682
# Train Epoch: 18 [2240/2444 (92%)]	Loss: 0.000965
# Train Epoch: 18 [2400/2444 (98%)]	Loss: 0.006391
# epoch:18,loss:0.006616622229427056
# 131 9
#
# Val set: Average loss: 1.1713, Accuracy: 103/131 (79%)
#
# 2444 153
# Train Epoch: 19 [160/2444 (7%)]	Loss: 0.000522
# Train Epoch: 19 [320/2444 (13%)]	Loss: 0.000471
# Train Epoch: 19 [480/2444 (20%)]	Loss: 0.001084
# Train Epoch: 19 [640/2444 (26%)]	Loss: 0.001280
# Train Epoch: 19 [800/2444 (33%)]	Loss: 0.000932
# Train Epoch: 19 [960/2444 (39%)]	Loss: 0.001265
# Train Epoch: 19 [1120/2444 (46%)]	Loss: 0.001220
# Train Epoch: 19 [1280/2444 (52%)]	Loss: 0.000510
# Train Epoch: 19 [1440/2444 (59%)]	Loss: 0.013679
# Train Epoch: 19 [1600/2444 (65%)]	Loss: 0.000480
# Train Epoch: 19 [1760/2444 (72%)]	Loss: 0.000896
# Train Epoch: 19 [1920/2444 (78%)]	Loss: 0.000861
# Train Epoch: 19 [2080/2444 (85%)]	Loss: 0.022119
# Train Epoch: 19 [2240/2444 (92%)]	Loss: 0.063078
# Train Epoch: 19 [2400/2444 (98%)]	Loss: 0.001961
# epoch:19,loss:0.0052411285726645706
# 131 9
#
# Val set: Average loss: 1.1665, Accuracy: 101/131 (77%)
#
# 2444 153
# Train Epoch: 20 [160/2444 (7%)]	Loss: 0.002000
# Train Epoch: 20 [320/2444 (13%)]	Loss: 0.000248
# Train Epoch: 20 [480/2444 (20%)]	Loss: 0.003904
# Train Epoch: 20 [640/2444 (26%)]	Loss: 0.000172
# Train Epoch: 20 [800/2444 (33%)]	Loss: 0.000679
# Train Epoch: 20 [960/2444 (39%)]	Loss: 0.003971
# Train Epoch: 20 [1120/2444 (46%)]	Loss: 0.006465
# Train Epoch: 20 [1280/2444 (52%)]	Loss: 0.001777
# Train Epoch: 20 [1440/2444 (59%)]	Loss: 0.000962
# Train Epoch: 20 [1600/2444 (65%)]	Loss: 0.000257
# Train Epoch: 20 [1760/2444 (72%)]	Loss: 0.016374
# Train Epoch: 20 [1920/2444 (78%)]	Loss: 0.001586
# Train Epoch: 20 [2080/2444 (85%)]	Loss: 0.000509
# Train Epoch: 20 [2240/2444 (92%)]	Loss: 0.003592
# Train Epoch: 20 [2400/2444 (98%)]	Loss: 0.003235
# epoch:20,loss:0.003974130352539789
# 131 9
#
# Val set: Average loss: 1.0573, Accuracy: 105/131 (80%)
#
# 2444 153
# Train Epoch: 21 [160/2444 (7%)]	Loss: 0.001935
# Train Epoch: 21 [320/2444 (13%)]	Loss: 0.002437
# Train Epoch: 21 [480/2444 (20%)]	Loss: 0.000584
# Train Epoch: 21 [640/2444 (26%)]	Loss: 0.001072
# Train Epoch: 21 [800/2444 (33%)]	Loss: 0.001518
# Train Epoch: 21 [960/2444 (39%)]	Loss: 0.000211
# Train Epoch: 21 [1120/2444 (46%)]	Loss: 0.002993
# Train Epoch: 21 [1280/2444 (52%)]	Loss: 0.000648
# Train Epoch: 21 [1440/2444 (59%)]	Loss: 0.000322
# Train Epoch: 21 [1600/2444 (65%)]	Loss: 0.001668
# Train Epoch: 21 [1760/2444 (72%)]	Loss: 0.000815
# Train Epoch: 21 [1920/2444 (78%)]	Loss: 0.000490
# Train Epoch: 21 [2080/2444 (85%)]	Loss: 0.004371
# Train Epoch: 21 [2240/2444 (92%)]	Loss: 0.001166
# Train Epoch: 21 [2400/2444 (98%)]	Loss: 0.001692
# epoch:21,loss:0.004723011872318749
# 131 9
#
# Val set: Average loss: 1.1558, Accuracy: 104/131 (79%)
#
# 2444 153
# Train Epoch: 22 [160/2444 (7%)]	Loss: 0.002453
# Train Epoch: 22 [320/2444 (13%)]	Loss: 0.001041
# Train Epoch: 22 [480/2444 (20%)]	Loss: 0.001432
# Train Epoch: 22 [640/2444 (26%)]	Loss: 0.002288
# Train Epoch: 22 [800/2444 (33%)]	Loss: 0.001035
# Train Epoch: 22 [960/2444 (39%)]	Loss: 0.001404
# Train Epoch: 22 [1120/2444 (46%)]	Loss: 0.010844
# Train Epoch: 22 [1280/2444 (52%)]	Loss: 0.001401
# Train Epoch: 22 [1440/2444 (59%)]	Loss: 0.001007
# Train Epoch: 22 [1600/2444 (65%)]	Loss: 0.001415
# Train Epoch: 22 [1760/2444 (72%)]	Loss: 0.003696
# Train Epoch: 22 [1920/2444 (78%)]	Loss: 0.000218
# Train Epoch: 22 [2080/2444 (85%)]	Loss: 0.000640
# Train Epoch: 22 [2240/2444 (92%)]	Loss: 0.000297
# Train Epoch: 22 [2400/2444 (98%)]	Loss: 0.001382
# epoch:22,loss:0.00566475676133254
# 131 9
#
# Val set: Average loss: 1.1455, Accuracy: 104/131 (79%)
#
# 2444 153
# Train Epoch: 23 [160/2444 (7%)]	Loss: 0.000583
# Train Epoch: 23 [320/2444 (13%)]	Loss: 0.001280
# Train Epoch: 23 [480/2444 (20%)]	Loss: 0.001480
# Train Epoch: 23 [640/2444 (26%)]	Loss: 0.003871
# Train Epoch: 23 [800/2444 (33%)]	Loss: 0.000970
# Train Epoch: 23 [960/2444 (39%)]	Loss: 0.001059
# Train Epoch: 23 [1120/2444 (46%)]	Loss: 0.017629
# Train Epoch: 23 [1280/2444 (52%)]	Loss: 0.000823
# Train Epoch: 23 [1440/2444 (59%)]	Loss: 0.000111
# Train Epoch: 23 [1600/2444 (65%)]	Loss: 0.002152
# Train Epoch: 23 [1760/2444 (72%)]	Loss: 0.000859
# Train Epoch: 23 [1920/2444 (78%)]	Loss: 0.000433
# Train Epoch: 23 [2080/2444 (85%)]	Loss: 0.011792
# Train Epoch: 23 [2240/2444 (92%)]	Loss: 0.001567
# Train Epoch: 23 [2400/2444 (98%)]	Loss: 0.001249
# epoch:23,loss:0.006106936309663153
# 131 9
#
# Val set: Average loss: 1.0605, Accuracy: 103/131 (79%)
#
# 2444 153
# Train Epoch: 24 [160/2444 (7%)]	Loss: 0.000792
# Train Epoch: 24 [320/2444 (13%)]	Loss: 0.000297
# Train Epoch: 24 [480/2444 (20%)]	Loss: 0.000892
# Train Epoch: 24 [640/2444 (26%)]	Loss: 0.045438
# Train Epoch: 24 [800/2444 (33%)]	Loss: 0.001666
# Train Epoch: 24 [960/2444 (39%)]	Loss: 0.001577
# Train Epoch: 24 [1120/2444 (46%)]	Loss: 0.000619
# Train Epoch: 24 [1280/2444 (52%)]	Loss: 0.000991
# Train Epoch: 24 [1440/2444 (59%)]	Loss: 0.001643
# Train Epoch: 24 [1600/2444 (65%)]	Loss: 0.001051
# Train Epoch: 24 [1760/2444 (72%)]	Loss: 0.001116
# Train Epoch: 24 [1920/2444 (78%)]	Loss: 0.001070
# Train Epoch: 24 [2080/2444 (85%)]	Loss: 0.000223
# Train Epoch: 24 [2240/2444 (92%)]	Loss: 0.001953
# Train Epoch: 24 [2400/2444 (98%)]	Loss: 0.204777
# epoch:24,loss:0.006225756608211098
# 131 9
#
# Val set: Average loss: 1.0976, Accuracy: 101/131 (77%)
#
# 2444 153
# Train Epoch: 25 [160/2444 (7%)]	Loss: 0.000457
# Train Epoch: 25 [320/2444 (13%)]	Loss: 0.001095
# Train Epoch: 25 [480/2444 (20%)]	Loss: 0.000142
# Train Epoch: 25 [640/2444 (26%)]	Loss: 0.000249
# Train Epoch: 25 [800/2444 (33%)]	Loss: 0.000668
# Train Epoch: 25 [960/2444 (39%)]	Loss: 0.003457
# Train Epoch: 25 [1120/2444 (46%)]	Loss: 0.000686
# Train Epoch: 25 [1280/2444 (52%)]	Loss: 0.001016
# Train Epoch: 25 [1440/2444 (59%)]	Loss: 0.003028
# Train Epoch: 25 [1600/2444 (65%)]	Loss: 0.002532
# Train Epoch: 25 [1760/2444 (72%)]	Loss: 0.003329
# Train Epoch: 25 [1920/2444 (78%)]	Loss: 0.001788
# Train Epoch: 25 [2080/2444 (85%)]	Loss: 0.001318
# Train Epoch: 25 [2240/2444 (92%)]	Loss: 0.000223
# Train Epoch: 25 [2400/2444 (98%)]	Loss: 0.005171
# epoch:25,loss:0.007364310302494952
# 131 9
#
# Val set: Average loss: 1.0970, Accuracy: 105/131 (80%)
#
# 2444 153
# Train Epoch: 26 [160/2444 (7%)]	Loss: 0.000798
# Train Epoch: 26 [320/2444 (13%)]	Loss: 0.000607
# Train Epoch: 26 [480/2444 (20%)]	Loss: 0.000953
# Train Epoch: 26 [640/2444 (26%)]	Loss: 0.014223
# Train Epoch: 26 [800/2444 (33%)]	Loss: 0.002423
# Train Epoch: 26 [960/2444 (39%)]	Loss: 0.000876
# Train Epoch: 26 [1120/2444 (46%)]	Loss: 0.000929
# Train Epoch: 26 [1280/2444 (52%)]	Loss: 0.001356
# Train Epoch: 26 [1440/2444 (59%)]	Loss: 0.000806
# Train Epoch: 26 [1600/2444 (65%)]	Loss: 0.002449
# Train Epoch: 26 [1760/2444 (72%)]	Loss: 0.002863
# Train Epoch: 26 [1920/2444 (78%)]	Loss: 0.001791
# Train Epoch: 26 [2080/2444 (85%)]	Loss: 0.001805
# Train Epoch: 26 [2240/2444 (92%)]	Loss: 0.006640
# Train Epoch: 26 [2400/2444 (98%)]	Loss: 0.000834
# epoch:26,loss:0.006620943183591057
# 131 9
#
# Val set: Average loss: 1.2027, Accuracy: 103/131 (79%)
#
# 2444 153
# Train Epoch: 27 [160/2444 (7%)]	Loss: 0.000116
# Train Epoch: 27 [320/2444 (13%)]	Loss: 0.000309
# Train Epoch: 27 [480/2444 (20%)]	Loss: 0.000381
# Train Epoch: 27 [640/2444 (26%)]	Loss: 0.000247
# Train Epoch: 27 [800/2444 (33%)]	Loss: 0.003379
# Train Epoch: 27 [960/2444 (39%)]	Loss: 0.001787
# Train Epoch: 27 [1120/2444 (46%)]	Loss: 0.000507
# Train Epoch: 27 [1280/2444 (52%)]	Loss: 0.005052
# Train Epoch: 27 [1440/2444 (59%)]	Loss: 0.000389
# Train Epoch: 27 [1600/2444 (65%)]	Loss: 0.002137
# Train Epoch: 27 [1760/2444 (72%)]	Loss: 0.007243
# Train Epoch: 27 [1920/2444 (78%)]	Loss: 0.009932
# Train Epoch: 27 [2080/2444 (85%)]	Loss: 0.007870
# Train Epoch: 27 [2240/2444 (92%)]	Loss: 0.002442
# Train Epoch: 27 [2400/2444 (98%)]	Loss: 0.040608
# epoch:27,loss:0.02543803708553824
# 131 9
#
# Val set: Average loss: 1.6767, Accuracy: 93/131 (71%)
#
# 2444 153
# Train Epoch: 28 [160/2444 (7%)]	Loss: 0.006333
# Train Epoch: 28 [320/2444 (13%)]	Loss: 0.000354
# Train Epoch: 28 [480/2444 (20%)]	Loss: 0.005106
# Train Epoch: 28 [640/2444 (26%)]	Loss: 0.003438
# Train Epoch: 28 [800/2444 (33%)]	Loss: 0.002700
# Train Epoch: 28 [960/2444 (39%)]	Loss: 0.099350
# Train Epoch: 28 [1120/2444 (46%)]	Loss: 0.430866
# Train Epoch: 28 [1280/2444 (52%)]	Loss: 0.296432
# Train Epoch: 28 [1440/2444 (59%)]	Loss: 0.106781
# Train Epoch: 28 [1600/2444 (65%)]	Loss: 0.004072
# Train Epoch: 28 [1760/2444 (72%)]	Loss: 0.045420
# Train Epoch: 28 [1920/2444 (78%)]	Loss: 0.018972
# Train Epoch: 28 [2080/2444 (85%)]	Loss: 0.047457
# Train Epoch: 28 [2240/2444 (92%)]	Loss: 0.004091
# Train Epoch: 28 [2400/2444 (98%)]	Loss: 0.130052
# epoch:28,loss:0.09443286674027179
# 131 9
#
# Val set: Average loss: 1.3532, Accuracy: 101/131 (77%)
#
# 2444 153
# Train Epoch: 29 [160/2444 (7%)]	Loss: 0.140198
# Train Epoch: 29 [320/2444 (13%)]	Loss: 0.342064
# Train Epoch: 29 [480/2444 (20%)]	Loss: 0.058277
# Train Epoch: 29 [640/2444 (26%)]	Loss: 0.015699
# Train Epoch: 29 [800/2444 (33%)]	Loss: 0.006590
# Train Epoch: 29 [960/2444 (39%)]	Loss: 0.066370
# Train Epoch: 29 [1120/2444 (46%)]	Loss: 0.022825
# Train Epoch: 29 [1280/2444 (52%)]	Loss: 0.002096
# Train Epoch: 29 [1440/2444 (59%)]	Loss: 0.014785
# Train Epoch: 29 [1600/2444 (65%)]	Loss: 0.012581
# Train Epoch: 29 [1760/2444 (72%)]	Loss: 0.051654
# Train Epoch: 29 [1920/2444 (78%)]	Loss: 0.061406
# Train Epoch: 29 [2080/2444 (85%)]	Loss: 0.047917
# Train Epoch: 29 [2240/2444 (92%)]	Loss: 0.000867
# Train Epoch: 29 [2400/2444 (98%)]	Loss: 0.030620
# epoch:29,loss:0.09548576393741445
# 131 9
#
# Val set: Average loss: 1.6216, Accuracy: 96/131 (73%)
#
# 2444 153
# Train Epoch: 30 [160/2444 (7%)]	Loss: 0.009134
# Train Epoch: 30 [320/2444 (13%)]	Loss: 0.039366
# Train Epoch: 30 [480/2444 (20%)]	Loss: 0.013890
# Train Epoch: 30 [640/2444 (26%)]	Loss: 0.101538
# Train Epoch: 30 [800/2444 (33%)]	Loss: 0.182813
# Train Epoch: 30 [960/2444 (39%)]	Loss: 0.009993
# Train Epoch: 30 [1120/2444 (46%)]	Loss: 0.360420
# Train Epoch: 30 [1280/2444 (52%)]	Loss: 0.128556
# Train Epoch: 30 [1440/2444 (59%)]	Loss: 0.122699
# Train Epoch: 30 [1600/2444 (65%)]	Loss: 0.160791
# Train Epoch: 30 [1760/2444 (72%)]	Loss: 0.181557
# Train Epoch: 30 [1920/2444 (78%)]	Loss: 0.025360
# Train Epoch: 30 [2080/2444 (85%)]	Loss: 0.143966
# Train Epoch: 30 [2240/2444 (92%)]	Loss: 0.003922
# Train Epoch: 30 [2400/2444 (98%)]	Loss: 0.251525
# epoch:30,loss:0.15355768611615073
# 131 9
#
# Val set: Average loss: 1.8697, Accuracy: 96/131 (73%)
#
# 2444 153
# Train Epoch: 31 [160/2444 (7%)]	Loss: 0.026196
# Train Epoch: 31 [320/2444 (13%)]	Loss: 0.028390
# Train Epoch: 31 [480/2444 (20%)]	Loss: 0.076175
# Train Epoch: 31 [640/2444 (26%)]	Loss: 0.274124
# Train Epoch: 31 [800/2444 (33%)]	Loss: 0.027379
# Train Epoch: 31 [960/2444 (39%)]	Loss: 0.059257
# Train Epoch: 31 [1120/2444 (46%)]	Loss: 0.002233
# Train Epoch: 31 [1280/2444 (52%)]	Loss: 0.269516
# Train Epoch: 31 [1440/2444 (59%)]	Loss: 0.150859
# Train Epoch: 31 [1600/2444 (65%)]	Loss: 0.041774
# Train Epoch: 31 [1760/2444 (72%)]	Loss: 0.207393
# Train Epoch: 31 [1920/2444 (78%)]	Loss: 0.020583
# Train Epoch: 31 [2080/2444 (85%)]	Loss: 0.115777
# Train Epoch: 31 [2240/2444 (92%)]	Loss: 0.100453
# Train Epoch: 31 [2400/2444 (98%)]	Loss: 0.091844
# epoch:31,loss:0.13867866422287098
# 131 9
#
# Val set: Average loss: 1.9140, Accuracy: 98/131 (75%)
#
# 2444 153
# Train Epoch: 32 [160/2444 (7%)]	Loss: 0.001934
# Train Epoch: 32 [320/2444 (13%)]	Loss: 0.160143
# Train Epoch: 32 [480/2444 (20%)]	Loss: 0.320762
# Train Epoch: 32 [640/2444 (26%)]	Loss: 0.026471
# Train Epoch: 32 [800/2444 (33%)]	Loss: 0.088345
# Train Epoch: 32 [960/2444 (39%)]	Loss: 0.253154
# Train Epoch: 32 [1120/2444 (46%)]	Loss: 0.200171
# Train Epoch: 32 [1280/2444 (52%)]	Loss: 0.470638
# Train Epoch: 32 [1440/2444 (59%)]	Loss: 1.453258
# Train Epoch: 32 [1600/2444 (65%)]	Loss: 0.159361
# Train Epoch: 32 [1760/2444 (72%)]	Loss: 0.156916
# Train Epoch: 32 [1920/2444 (78%)]	Loss: 0.012729
# Train Epoch: 32 [2080/2444 (85%)]	Loss: 0.389899
# Train Epoch: 32 [2240/2444 (92%)]	Loss: 0.357484
# Train Epoch: 32 [2400/2444 (98%)]	Loss: 0.329537
# epoch:32,loss:0.21692333238053263
# 131 9
#
# Val set: Average loss: 1.0620, Accuracy: 96/131 (73%)
#
# 2444 153
# Train Epoch: 33 [160/2444 (7%)]	Loss: 0.064779
# Train Epoch: 33 [320/2444 (13%)]	Loss: 0.102931
# Train Epoch: 33 [480/2444 (20%)]	Loss: 0.438993
# Train Epoch: 33 [640/2444 (26%)]	Loss: 0.787149
# Train Epoch: 33 [800/2444 (33%)]	Loss: 0.218319
# Train Epoch: 33 [960/2444 (39%)]	Loss: 0.144460
# Train Epoch: 33 [1120/2444 (46%)]	Loss: 0.200331
# Train Epoch: 33 [1280/2444 (52%)]	Loss: 0.180591
# Train Epoch: 33 [1440/2444 (59%)]	Loss: 0.057047
# Train Epoch: 33 [1600/2444 (65%)]	Loss: 0.000841
# Train Epoch: 33 [1760/2444 (72%)]	Loss: 0.000868
# Train Epoch: 33 [1920/2444 (78%)]	Loss: 0.358145
# Train Epoch: 33 [2080/2444 (85%)]	Loss: 0.000811
# Train Epoch: 33 [2240/2444 (92%)]	Loss: 0.050961
# Train Epoch: 33 [2400/2444 (98%)]	Loss: 0.007936
# epoch:33,loss:0.12399227208487562
# 131 9
#
# Val set: Average loss: 1.6619, Accuracy: 93/131 (71%)
#
# 2444 153
# Train Epoch: 34 [160/2444 (7%)]	Loss: 0.003249
# Train Epoch: 34 [320/2444 (13%)]	Loss: 0.013069
# Train Epoch: 34 [480/2444 (20%)]	Loss: 0.007513
# Train Epoch: 34 [640/2444 (26%)]	Loss: 0.004841
# Train Epoch: 34 [800/2444 (33%)]	Loss: 0.061521
# Train Epoch: 34 [960/2444 (39%)]	Loss: 0.021935
# Train Epoch: 34 [1120/2444 (46%)]	Loss: 0.003033
# Train Epoch: 34 [1280/2444 (52%)]	Loss: 0.003379
# Train Epoch: 34 [1440/2444 (59%)]	Loss: 0.016023
# Train Epoch: 34 [1600/2444 (65%)]	Loss: 0.023888
# Train Epoch: 34 [1760/2444 (72%)]	Loss: 0.252379
# Train Epoch: 34 [1920/2444 (78%)]	Loss: 0.069970
# Train Epoch: 34 [2080/2444 (85%)]	Loss: 0.096968
# Train Epoch: 34 [2240/2444 (92%)]	Loss: 0.001596
# Train Epoch: 34 [2400/2444 (98%)]	Loss: 0.000344
# epoch:34,loss:0.07431363966753493
# 131 9
#
# Val set: Average loss: 1.3692, Accuracy: 98/131 (75%)
#
# 2444 153
# Train Epoch: 35 [160/2444 (7%)]	Loss: 0.072937
# Train Epoch: 35 [320/2444 (13%)]	Loss: 0.020532
# Train Epoch: 35 [480/2444 (20%)]	Loss: 0.018139
# Train Epoch: 35 [640/2444 (26%)]	Loss: 0.005073
# Train Epoch: 35 [800/2444 (33%)]	Loss: 0.040969
# Train Epoch: 35 [960/2444 (39%)]	Loss: 0.033286
# Train Epoch: 35 [1120/2444 (46%)]	Loss: 0.015920
# Train Epoch: 35 [1280/2444 (52%)]	Loss: 0.186066
# Train Epoch: 35 [1440/2444 (59%)]	Loss: 0.373914
# Train Epoch: 35 [1600/2444 (65%)]	Loss: 0.410624
# Train Epoch: 35 [1760/2444 (72%)]	Loss: 0.365744
# Train Epoch: 35 [1920/2444 (78%)]	Loss: 0.049429
# Train Epoch: 35 [2080/2444 (85%)]	Loss: 1.437617
# Train Epoch: 35 [2240/2444 (92%)]	Loss: 1.440575
# Train Epoch: 35 [2400/2444 (98%)]	Loss: 0.231893
# epoch:35,loss:0.26008367453917886
# 131 9
#
# Val set: Average loss: 1.7929, Accuracy: 86/131 (66%)
#
# 2444 153
# Train Epoch: 36 [160/2444 (7%)]	Loss: 0.307448
# Train Epoch: 36 [320/2444 (13%)]	Loss: 1.131988
# Train Epoch: 36 [480/2444 (20%)]	Loss: 0.001193
# Train Epoch: 36 [640/2444 (26%)]	Loss: 0.023502
# Train Epoch: 36 [800/2444 (33%)]	Loss: 0.182642
# Train Epoch: 36 [960/2444 (39%)]	Loss: 0.013444
# Train Epoch: 36 [1120/2444 (46%)]	Loss: 0.011253
# Train Epoch: 36 [1280/2444 (52%)]	Loss: 0.165891
# Train Epoch: 36 [1440/2444 (59%)]	Loss: 0.117676
# Train Epoch: 36 [1600/2444 (65%)]	Loss: 0.251159
# Train Epoch: 36 [1760/2444 (72%)]	Loss: 0.042134
# Train Epoch: 36 [1920/2444 (78%)]	Loss: 0.192083
# Train Epoch: 36 [2080/2444 (85%)]	Loss: 0.029669
# Train Epoch: 36 [2240/2444 (92%)]	Loss: 0.024699
# Train Epoch: 36 [2400/2444 (98%)]	Loss: 0.156965
# epoch:36,loss:0.19458855616287907
# 131 9
#
# Val set: Average loss: 1.5795, Accuracy: 94/131 (72%)
#
# 2444 153
# Train Epoch: 37 [160/2444 (7%)]	Loss: 0.117802
# Train Epoch: 37 [320/2444 (13%)]	Loss: 0.051373
# Train Epoch: 37 [480/2444 (20%)]	Loss: 0.331391
# Train Epoch: 37 [640/2444 (26%)]	Loss: 0.062890
# Train Epoch: 37 [800/2444 (33%)]	Loss: 0.064035
# Train Epoch: 37 [960/2444 (39%)]	Loss: 0.094664
# Train Epoch: 37 [1120/2444 (46%)]	Loss: 0.004057
# Train Epoch: 37 [1280/2444 (52%)]	Loss: 0.160517
# Train Epoch: 37 [1440/2444 (59%)]	Loss: 0.000456
# Train Epoch: 37 [1600/2444 (65%)]	Loss: 0.277309
# Train Epoch: 37 [1760/2444 (72%)]	Loss: 0.013486
# Train Epoch: 37 [1920/2444 (78%)]	Loss: 0.013997
# Train Epoch: 37 [2080/2444 (85%)]	Loss: 0.105096
# Train Epoch: 37 [2240/2444 (92%)]	Loss: 0.041711
# Train Epoch: 37 [2400/2444 (98%)]	Loss: 0.115570
# epoch:37,loss:0.21740557000347643
# 131 9
#
# Val set: Average loss: 1.6993, Accuracy: 94/131 (72%)
#
# 2444 153
# Train Epoch: 38 [160/2444 (7%)]	Loss: 0.064603
# Train Epoch: 38 [320/2444 (13%)]	Loss: 0.020775
# Train Epoch: 38 [480/2444 (20%)]	Loss: 0.123709
# Train Epoch: 38 [640/2444 (26%)]	Loss: 0.398162
# Train Epoch: 38 [800/2444 (33%)]	Loss: 0.010343
# Train Epoch: 38 [960/2444 (39%)]	Loss: 0.002750
# Train Epoch: 38 [1120/2444 (46%)]	Loss: 0.320506
# Train Epoch: 38 [1280/2444 (52%)]	Loss: 0.123966
# Train Epoch: 38 [1440/2444 (59%)]	Loss: 0.201222
# Train Epoch: 38 [1600/2444 (65%)]	Loss: 0.003515
# Train Epoch: 38 [1760/2444 (72%)]	Loss: 0.850890
# Train Epoch: 38 [1920/2444 (78%)]	Loss: 0.071257
# Train Epoch: 38 [2080/2444 (85%)]	Loss: 0.020048
# Train Epoch: 38 [2240/2444 (92%)]	Loss: 0.156621
# Train Epoch: 38 [2400/2444 (98%)]	Loss: 0.065169
# epoch:38,loss:0.14624576133545
# 131 9
#
# Val set: Average loss: 1.6064, Accuracy: 98/131 (75%)
#
# 2444 153
# Train Epoch: 39 [160/2444 (7%)]	Loss: 0.013189
# Train Epoch: 39 [320/2444 (13%)]	Loss: 0.012434
# Train Epoch: 39 [480/2444 (20%)]	Loss: 0.013699
# Train Epoch: 39 [640/2444 (26%)]	Loss: 0.007236
# Train Epoch: 39 [800/2444 (33%)]	Loss: 0.010791
# Train Epoch: 39 [960/2444 (39%)]	Loss: 0.068478
# Train Epoch: 39 [1120/2444 (46%)]	Loss: 0.112350
# Train Epoch: 39 [1280/2444 (52%)]	Loss: 0.002174
# Train Epoch: 39 [1440/2444 (59%)]	Loss: 0.032878
# Train Epoch: 39 [1600/2444 (65%)]	Loss: 0.002062
# Train Epoch: 39 [1760/2444 (72%)]	Loss: 0.002698
# Train Epoch: 39 [1920/2444 (78%)]	Loss: 0.012266
# Train Epoch: 39 [2080/2444 (85%)]	Loss: 0.096763
# Train Epoch: 39 [2240/2444 (92%)]	Loss: 0.205948
# Train Epoch: 39 [2400/2444 (98%)]	Loss: 0.119454
# epoch:39,loss:0.10557172633212948
# 131 9
#
# Val set: Average loss: 1.4624, Accuracy: 96/131 (73%)
#
# 2444 153
# Train Epoch: 40 [160/2444 (7%)]	Loss: 0.041590
# Train Epoch: 40 [320/2444 (13%)]	Loss: 0.013949
# Train Epoch: 40 [480/2444 (20%)]	Loss: 0.419911
# Train Epoch: 40 [640/2444 (26%)]	Loss: 0.017239
# Train Epoch: 40 [800/2444 (33%)]	Loss: 0.008911
# Train Epoch: 40 [960/2444 (39%)]	Loss: 0.208008
# Train Epoch: 40 [1120/2444 (46%)]	Loss: 0.088425
# Train Epoch: 40 [1280/2444 (52%)]	Loss: 0.003520
# Train Epoch: 40 [1440/2444 (59%)]	Loss: 0.460840
# Train Epoch: 40 [1600/2444 (65%)]	Loss: 0.012548
# Train Epoch: 40 [1760/2444 (72%)]	Loss: 0.049036
# Train Epoch: 40 [1920/2444 (78%)]	Loss: 0.951398
# Train Epoch: 40 [2080/2444 (85%)]	Loss: 0.008725
# Train Epoch: 40 [2240/2444 (92%)]	Loss: 0.132810
# Train Epoch: 40 [2400/2444 (98%)]	Loss: 0.006929
# epoch:40,loss:0.1238133719482374
# 131 9
#
# Val set: Average loss: 1.4493, Accuracy: 88/131 (67%)
#
# 2444 153
# Train Epoch: 41 [160/2444 (7%)]	Loss: 0.061224
# Train Epoch: 41 [320/2444 (13%)]	Loss: 0.023724
# Train Epoch: 41 [480/2444 (20%)]	Loss: 0.002804
# Train Epoch: 41 [640/2444 (26%)]	Loss: 0.012534
# Train Epoch: 41 [800/2444 (33%)]	Loss: 0.019185
# Train Epoch: 41 [960/2444 (39%)]	Loss: 0.013400
# Train Epoch: 41 [1120/2444 (46%)]	Loss: 0.005130
# Train Epoch: 41 [1280/2444 (52%)]	Loss: 0.000102
# Train Epoch: 41 [1440/2444 (59%)]	Loss: 0.005498
# Train Epoch: 41 [1600/2444 (65%)]	Loss: 0.030997
# Train Epoch: 41 [1760/2444 (72%)]	Loss: 0.001170
# Train Epoch: 41 [1920/2444 (78%)]	Loss: 0.186142
# Train Epoch: 41 [2080/2444 (85%)]	Loss: 0.000502
# Train Epoch: 41 [2240/2444 (92%)]	Loss: 0.554668
# Train Epoch: 41 [2400/2444 (98%)]	Loss: 0.024751
# epoch:41,loss:0.08156696578763194
# 131 9
#
# Val set: Average loss: 1.5998, Accuracy: 91/131 (69%)
#
# 2444 153
# Train Epoch: 42 [160/2444 (7%)]	Loss: 0.013118
# Train Epoch: 42 [320/2444 (13%)]	Loss: 0.017538
# Train Epoch: 42 [480/2444 (20%)]	Loss: 0.091826
# Train Epoch: 42 [640/2444 (26%)]	Loss: 0.016953
# Train Epoch: 42 [800/2444 (33%)]	Loss: 0.063152
# Train Epoch: 42 [960/2444 (39%)]	Loss: 0.165853
# Train Epoch: 42 [1120/2444 (46%)]	Loss: 0.104189
# Train Epoch: 42 [1280/2444 (52%)]	Loss: 0.214915
# Train Epoch: 42 [1440/2444 (59%)]	Loss: 0.169302
# Train Epoch: 42 [1600/2444 (65%)]	Loss: 0.313807
# Train Epoch: 42 [1760/2444 (72%)]	Loss: 0.005958
# Train Epoch: 42 [1920/2444 (78%)]	Loss: 0.241247
# Train Epoch: 42 [2080/2444 (85%)]	Loss: 0.005734
# Train Epoch: 42 [2240/2444 (92%)]	Loss: 0.297098
# Train Epoch: 42 [2400/2444 (98%)]	Loss: 0.010489
# epoch:42,loss:0.08230770167246387
# 131 9
#
# Val set: Average loss: 1.5093, Accuracy: 90/131 (69%)
#
# 2444 153
# Train Epoch: 43 [160/2444 (7%)]	Loss: 0.033760
# Train Epoch: 43 [320/2444 (13%)]	Loss: 0.003219
# Train Epoch: 43 [480/2444 (20%)]	Loss: 0.001172
# Train Epoch: 43 [640/2444 (26%)]	Loss: 0.001145
# Train Epoch: 43 [800/2444 (33%)]	Loss: 0.005099
# Train Epoch: 43 [960/2444 (39%)]	Loss: 0.002218
# Train Epoch: 43 [1120/2444 (46%)]	Loss: 0.021287
# Train Epoch: 43 [1280/2444 (52%)]	Loss: 0.000917
# Train Epoch: 43 [1440/2444 (59%)]	Loss: 0.176540
# Train Epoch: 43 [1600/2444 (65%)]	Loss: 0.020233
# Train Epoch: 43 [1760/2444 (72%)]	Loss: 0.001643
# Train Epoch: 43 [1920/2444 (78%)]	Loss: 0.005514
# Train Epoch: 43 [2080/2444 (85%)]	Loss: 0.006019
# Train Epoch: 43 [2240/2444 (92%)]	Loss: 0.004224
# Train Epoch: 43 [2400/2444 (98%)]	Loss: 0.079044
# epoch:43,loss:0.04679640314885677
# 131 9
#
# Val set: Average loss: 1.2041, Accuracy: 97/131 (74%)
#
# 2444 153
# Train Epoch: 44 [160/2444 (7%)]	Loss: 0.003102
# Train Epoch: 44 [320/2444 (13%)]	Loss: 0.004700
# Train Epoch: 44 [480/2444 (20%)]	Loss: 0.005184
# Train Epoch: 44 [640/2444 (26%)]	Loss: 0.000487
# Train Epoch: 44 [800/2444 (33%)]	Loss: 0.000258
# Train Epoch: 44 [960/2444 (39%)]	Loss: 0.179605
# Train Epoch: 44 [1120/2444 (46%)]	Loss: 0.008441
# Train Epoch: 44 [1280/2444 (52%)]	Loss: 0.020128
# Train Epoch: 44 [1440/2444 (59%)]	Loss: 0.089815
# Train Epoch: 44 [1600/2444 (65%)]	Loss: 0.053661
# Train Epoch: 44 [1760/2444 (72%)]	Loss: 0.001932
# Train Epoch: 44 [1920/2444 (78%)]	Loss: 0.007689
# Train Epoch: 44 [2080/2444 (85%)]	Loss: 0.006001
# Train Epoch: 44 [2240/2444 (92%)]	Loss: 0.040454
# Train Epoch: 44 [2400/2444 (98%)]	Loss: 0.015313
# epoch:44,loss:0.0697255663363928
# 131 9
#
# Val set: Average loss: 1.8258, Accuracy: 95/131 (73%)
#
# 2444 153
# Train Epoch: 45 [160/2444 (7%)]	Loss: 0.023756
# Train Epoch: 45 [320/2444 (13%)]	Loss: 0.003305
# Train Epoch: 45 [480/2444 (20%)]	Loss: 0.001532
# Train Epoch: 45 [640/2444 (26%)]	Loss: 0.019268
# Train Epoch: 45 [800/2444 (33%)]	Loss: 0.029184
# Train Epoch: 45 [960/2444 (39%)]	Loss: 0.048137
# Train Epoch: 45 [1120/2444 (46%)]	Loss: 0.014761
# Train Epoch: 45 [1280/2444 (52%)]	Loss: 0.008273
# Train Epoch: 45 [1440/2444 (59%)]	Loss: 0.001074
# Train Epoch: 45 [1600/2444 (65%)]	Loss: 0.002111
# Train Epoch: 45 [1760/2444 (72%)]	Loss: 0.004347
# Train Epoch: 45 [1920/2444 (78%)]	Loss: 0.000480
# Train Epoch: 45 [2080/2444 (85%)]	Loss: 0.002293
# Train Epoch: 45 [2240/2444 (92%)]	Loss: 0.046820
# Train Epoch: 45 [2400/2444 (98%)]	Loss: 0.000206
# epoch:45,loss:0.060102015142368986
# 131 9
#
# Val set: Average loss: 1.1909, Accuracy: 97/131 (74%)
#
# 2444 153
# Train Epoch: 46 [160/2444 (7%)]	Loss: 0.004469
# Train Epoch: 46 [320/2444 (13%)]	Loss: 0.218329
# Train Epoch: 46 [480/2444 (20%)]	Loss: 0.005505
# Train Epoch: 46 [640/2444 (26%)]	Loss: 0.062816
# Train Epoch: 46 [800/2444 (33%)]	Loss: 0.001283
# Train Epoch: 46 [960/2444 (39%)]	Loss: 0.000125
# Train Epoch: 46 [1120/2444 (46%)]	Loss: 0.082771
# Train Epoch: 46 [1280/2444 (52%)]	Loss: 0.000244
# Train Epoch: 46 [1440/2444 (59%)]	Loss: 0.007706
# Train Epoch: 46 [1600/2444 (65%)]	Loss: 0.001876
# Train Epoch: 46 [1760/2444 (72%)]	Loss: 0.001413
# Train Epoch: 46 [1920/2444 (78%)]	Loss: 0.277231
# Train Epoch: 46 [2080/2444 (85%)]	Loss: 0.006787
# Train Epoch: 46 [2240/2444 (92%)]	Loss: 0.000947
# Train Epoch: 46 [2400/2444 (98%)]	Loss: 0.000228
# epoch:46,loss:0.040652019121255
# 131 9
#
# Val set: Average loss: 1.5405, Accuracy: 94/131 (72%)
#
# 2444 153
# Train Epoch: 47 [160/2444 (7%)]	Loss: 0.000346
# Train Epoch: 47 [320/2444 (13%)]	Loss: 0.060581
# Train Epoch: 47 [480/2444 (20%)]	Loss: 0.000179
# Train Epoch: 47 [640/2444 (26%)]	Loss: 0.135519
# Train Epoch: 47 [800/2444 (33%)]	Loss: 0.088574
# Train Epoch: 47 [960/2444 (39%)]	Loss: 0.034840
# Train Epoch: 47 [1120/2444 (46%)]	Loss: 0.000550
# Train Epoch: 47 [1280/2444 (52%)]	Loss: 0.000925
# Train Epoch: 47 [1440/2444 (59%)]	Loss: 0.006575
# Train Epoch: 47 [1600/2444 (65%)]	Loss: 0.000626
# Train Epoch: 47 [1760/2444 (72%)]	Loss: 0.025133
# Train Epoch: 47 [1920/2444 (78%)]	Loss: 0.359620
# Train Epoch: 47 [2080/2444 (85%)]	Loss: 0.060430
# Train Epoch: 47 [2240/2444 (92%)]	Loss: 0.000216
# Train Epoch: 47 [2400/2444 (98%)]	Loss: 0.004330
# epoch:47,loss:0.033072334978023005
# 131 9
#
# Val set: Average loss: 1.2528, Accuracy: 101/131 (77%)
#
# 2444 153
# Train Epoch: 48 [160/2444 (7%)]	Loss: 0.026368
# Train Epoch: 48 [320/2444 (13%)]	Loss: 0.003692
# Train Epoch: 48 [480/2444 (20%)]	Loss: 0.004183
# Train Epoch: 48 [640/2444 (26%)]	Loss: 0.001400
# Train Epoch: 48 [800/2444 (33%)]	Loss: 0.001825
# Train Epoch: 48 [960/2444 (39%)]	Loss: 0.001269
# Train Epoch: 48 [1120/2444 (46%)]	Loss: 0.000247
# Train Epoch: 48 [1280/2444 (52%)]	Loss: 0.000838
# Train Epoch: 48 [1440/2444 (59%)]	Loss: 0.014635
# Train Epoch: 48 [1600/2444 (65%)]	Loss: 0.000470
# Train Epoch: 48 [1760/2444 (72%)]	Loss: 0.000384
# Train Epoch: 48 [1920/2444 (78%)]	Loss: 0.003476
# Train Epoch: 48 [2080/2444 (85%)]	Loss: 0.000159
# Train Epoch: 48 [2240/2444 (92%)]	Loss: 0.185309
# Train Epoch: 48 [2400/2444 (98%)]	Loss: 0.018524
# epoch:48,loss:0.014749588985152062
# 131 9
#
# Val set: Average loss: 1.1943, Accuracy: 100/131 (76%)
#
# 2444 153
# Train Epoch: 49 [160/2444 (7%)]	Loss: 0.001103
# Train Epoch: 49 [320/2444 (13%)]	Loss: 0.000046
# Train Epoch: 49 [480/2444 (20%)]	Loss: 0.008805
# Train Epoch: 49 [640/2444 (26%)]	Loss: 0.007384
# Train Epoch: 49 [800/2444 (33%)]	Loss: 0.002181
# Train Epoch: 49 [960/2444 (39%)]	Loss: 0.000649
# Train Epoch: 49 [1120/2444 (46%)]	Loss: 0.012033
# Train Epoch: 49 [1280/2444 (52%)]	Loss: 0.000537
# Train Epoch: 49 [1440/2444 (59%)]	Loss: 0.026813
# Train Epoch: 49 [1600/2444 (65%)]	Loss: 0.000749
# Train Epoch: 49 [1760/2444 (72%)]	Loss: 0.000093
# Train Epoch: 49 [1920/2444 (78%)]	Loss: 0.014981
# Train Epoch: 49 [2080/2444 (85%)]	Loss: 0.000223
# Train Epoch: 49 [2240/2444 (92%)]	Loss: 0.000683
# Train Epoch: 49 [2400/2444 (98%)]	Loss: 0.038114
# epoch:49,loss:0.01931790998718664
# 131 9
#
# Val set: Average loss: 1.8416, Accuracy: 101/131 (77%)
#
# 2444 153
# Train Epoch: 50 [160/2444 (7%)]	Loss: 0.024562
# Train Epoch: 50 [320/2444 (13%)]	Loss: 0.013031
# Train Epoch: 50 [480/2444 (20%)]	Loss: 0.000524
# Train Epoch: 50 [640/2444 (26%)]	Loss: 0.000219
# Train Epoch: 50 [800/2444 (33%)]	Loss: 0.065415
# Train Epoch: 50 [960/2444 (39%)]	Loss: 0.000782
# Train Epoch: 50 [1120/2444 (46%)]	Loss: 0.000315
# Train Epoch: 50 [1280/2444 (52%)]	Loss: 0.000009
# Train Epoch: 50 [1440/2444 (59%)]	Loss: 0.004200
# Train Epoch: 50 [1600/2444 (65%)]	Loss: 0.004153
# Train Epoch: 50 [1760/2444 (72%)]	Loss: 0.000038
# Train Epoch: 50 [1920/2444 (78%)]	Loss: 0.007799
# Train Epoch: 50 [2080/2444 (85%)]	Loss: 0.000426
# Train Epoch: 50 [2240/2444 (92%)]	Loss: 0.000268
# Train Epoch: 50 [2400/2444 (98%)]	Loss: 0.000152
# epoch:50,loss:0.010181488783696385
# 131 9
#
# Val set: Average loss: 1.4580, Accuracy: 102/131 (78%)
#
# 2444 153
# Train Epoch: 51 [160/2444 (7%)]	Loss: 0.002404
# Train Epoch: 51 [320/2444 (13%)]	Loss: 0.000398
# Train Epoch: 51 [480/2444 (20%)]	Loss: 0.000193
# Train Epoch: 51 [640/2444 (26%)]	Loss: 0.017046
# Train Epoch: 51 [800/2444 (33%)]	Loss: 0.000105
# Train Epoch: 51 [960/2444 (39%)]	Loss: 0.000160
# Train Epoch: 51 [1120/2444 (46%)]	Loss: 0.000541
# Train Epoch: 51 [1280/2444 (52%)]	Loss: 0.000038
# Train Epoch: 51 [1440/2444 (59%)]	Loss: 0.000019
# Train Epoch: 51 [1600/2444 (65%)]	Loss: 0.000037
# Train Epoch: 51 [1760/2444 (72%)]	Loss: 0.000594
# Train Epoch: 51 [1920/2444 (78%)]	Loss: 0.000467
# Train Epoch: 51 [2080/2444 (85%)]	Loss: 0.001899
# Train Epoch: 51 [2240/2444 (92%)]	Loss: 0.001052
# Train Epoch: 51 [2400/2444 (98%)]	Loss: 0.001116
# epoch:51,loss:0.009117140393957217
# 131 9
#
# Val set: Average loss: 1.5233, Accuracy: 100/131 (76%)
#
# 2444 153
# Train Epoch: 52 [160/2444 (7%)]	Loss: 0.017541
# Train Epoch: 52 [320/2444 (13%)]	Loss: 0.000172
# Train Epoch: 52 [480/2444 (20%)]	Loss: 0.009300
# Train Epoch: 52 [640/2444 (26%)]	Loss: 0.003147
# Train Epoch: 52 [800/2444 (33%)]	Loss: 0.000174
# Train Epoch: 52 [1120/2444 (46%)]	Loss: 0.000235
# Train Epoch: 52 [1280/2444 (52%)]	Loss: 0.003638
# Train Epoch: 52 [1440/2444 (59%)]	Loss: 0.000322
# Train Epoch: 52 [1600/2444 (65%)]	Loss: 0.000026
# Train Epoch: 52 [1760/2444 (72%)]	Loss: 0.000782
# Train Epoch: 52 [1920/2444 (78%)]	Loss: 0.000778
# Train Epoch: 52 [2080/2444 (85%)]	Loss: 0.000136
# Train Epoch: 52 [2240/2444 (92%)]	Loss: 0.000193
# Train Epoch: 52 [2400/2444 (98%)]	Loss: 0.000232
# epoch:52,loss:0.005278344741176018
# 131 9
#
# Val set: Average loss: 1.5024, Accuracy: 100/131 (76%)
#
# 2444 153
# Train Epoch: 53 [160/2444 (7%)]	Loss: 0.001575
# Train Epoch: 53 [320/2444 (13%)]	Loss: 0.000410
# Train Epoch: 53 [480/2444 (20%)]	Loss: 0.014363
# Train Epoch: 53 [640/2444 (26%)]	Loss: 0.000056
# Train Epoch: 53 [800/2444 (33%)]	Loss: 0.000008
# Train Epoch: 53 [960/2444 (39%)]	Loss: 0.000047
# Train Epoch: 53 [1120/2444 (46%)]	Loss: 0.000233
# Train Epoch: 53 [1280/2444 (52%)]	Loss: 0.000035
# Train Epoch: 53 [1440/2444 (59%)]	Loss: 0.000131
# Train Epoch: 53 [1600/2444 (65%)]	Loss: 0.000578
# Train Epoch: 53 [1760/2444 (72%)]	Loss: 0.000803
# Train Epoch: 53 [1920/2444 (78%)]	Loss: 0.000027
# Train Epoch: 53 [2080/2444 (85%)]	Loss: 0.000009
# Train Epoch: 53 [2240/2444 (92%)]	Loss: 0.000041
# Train Epoch: 53 [2400/2444 (98%)]	Loss: 0.000071
# epoch:53,loss:0.002396016325021823
# 131 9
#
# Val set: Average loss: 1.5544, Accuracy: 101/131 (77%)
#
# 2444 153
# Train Epoch: 54 [160/2444 (7%)]	Loss: 0.000507
# Train Epoch: 54 [320/2444 (13%)]	Loss: 0.000071
# Train Epoch: 54 [480/2444 (20%)]	Loss: 0.000119
# Train Epoch: 54 [640/2444 (26%)]	Loss: 0.000006
# Train Epoch: 54 [800/2444 (33%)]	Loss: 0.000833
# Train Epoch: 54 [960/2444 (39%)]	Loss: 0.000250
# Train Epoch: 54 [1120/2444 (46%)]	Loss: 0.000377
# Train Epoch: 54 [1280/2444 (52%)]	Loss: 0.000696
# Train Epoch: 54 [1440/2444 (59%)]	Loss: 0.001691
# Train Epoch: 54 [1600/2444 (65%)]	Loss: 0.000071
# Train Epoch: 54 [1760/2444 (72%)]	Loss: 0.000060
# Train Epoch: 54 [1920/2444 (78%)]	Loss: 0.000427
# Train Epoch: 54 [2080/2444 (85%)]	Loss: 0.000125
# Train Epoch: 54 [2240/2444 (92%)]	Loss: 0.001037
# Train Epoch: 54 [2400/2444 (98%)]	Loss: 0.000259
# epoch:54,loss:0.002652595882873178
# 131 9
#
# Val set: Average loss: 1.7096, Accuracy: 99/131 (76%)
#
# 2444 153
# Train Epoch: 55 [160/2444 (7%)]	Loss: 0.017264
# Train Epoch: 55 [320/2444 (13%)]	Loss: 0.000100
# Train Epoch: 55 [480/2444 (20%)]	Loss: 0.000028
# Train Epoch: 55 [640/2444 (26%)]	Loss: 0.000040
# Train Epoch: 55 [800/2444 (33%)]	Loss: 0.000161
# Train Epoch: 55 [960/2444 (39%)]	Loss: 0.000263
# Train Epoch: 55 [1120/2444 (46%)]	Loss: 0.000191
# Train Epoch: 55 [1280/2444 (52%)]	Loss: 0.000315
# Train Epoch: 55 [1440/2444 (59%)]	Loss: 0.000118
# Train Epoch: 55 [1600/2444 (65%)]	Loss: 0.000082
# Train Epoch: 55 [1760/2444 (72%)]	Loss: 0.000324
# Train Epoch: 55 [1920/2444 (78%)]	Loss: 0.000008
# Train Epoch: 55 [2080/2444 (85%)]	Loss: 0.000449
# Train Epoch: 55 [2240/2444 (92%)]	Loss: 0.000210
# Train Epoch: 55 [2400/2444 (98%)]	Loss: 0.000745
# epoch:55,loss:0.00305789154893265
# 131 9
#
# Val set: Average loss: 1.3937, Accuracy: 100/131 (76%)
#
# 2444 153
# Train Epoch: 56 [160/2444 (7%)]	Loss: 0.000222
# Train Epoch: 56 [320/2444 (13%)]	Loss: 0.000041
# Train Epoch: 56 [480/2444 (20%)]	Loss: 0.000005
# Train Epoch: 56 [640/2444 (26%)]	Loss: 0.000026
# Train Epoch: 56 [800/2444 (33%)]	Loss: 0.005399
# Train Epoch: 56 [960/2444 (39%)]	Loss: 0.000053
# Train Epoch: 56 [1120/2444 (46%)]	Loss: 0.000035
# Train Epoch: 56 [1280/2444 (52%)]	Loss: 0.208033
# Train Epoch: 56 [1440/2444 (59%)]	Loss: 0.000044
# Train Epoch: 56 [1600/2444 (65%)]	Loss: 0.000119
# Train Epoch: 56 [1760/2444 (72%)]	Loss: 0.000211
# Train Epoch: 56 [1920/2444 (78%)]	Loss: 0.000109
# Train Epoch: 56 [2080/2444 (85%)]	Loss: 0.000100
# Train Epoch: 56 [2240/2444 (92%)]	Loss: 0.000103
# Train Epoch: 56 [2400/2444 (98%)]	Loss: 0.000047
# epoch:56,loss:0.002950162595630436
# 131 9
#
# Val set: Average loss: 1.3639, Accuracy: 99/131 (76%)
#
# 2444 153
# Train Epoch: 57 [160/2444 (7%)]	Loss: 0.000275
# Train Epoch: 57 [320/2444 (13%)]	Loss: 0.000081
# Train Epoch: 57 [480/2444 (20%)]	Loss: 0.001255
# Train Epoch: 57 [640/2444 (26%)]	Loss: 0.000020
# Train Epoch: 57 [800/2444 (33%)]	Loss: 0.000110
# Train Epoch: 57 [960/2444 (39%)]	Loss: 0.000021
# Train Epoch: 57 [1120/2444 (46%)]	Loss: 0.000059
# Train Epoch: 57 [1280/2444 (52%)]	Loss: 0.001783
# Train Epoch: 57 [1440/2444 (59%)]	Loss: 0.000588
# Train Epoch: 57 [1600/2444 (65%)]	Loss: 0.000171
# Train Epoch: 57 [1760/2444 (72%)]	Loss: 0.001047
# Train Epoch: 57 [1920/2444 (78%)]	Loss: 0.000019
# Train Epoch: 57 [2080/2444 (85%)]	Loss: 0.006812
# Train Epoch: 57 [2240/2444 (92%)]	Loss: 0.000274
# Train Epoch: 57 [2400/2444 (98%)]	Loss: 0.000058
# epoch:57,loss:0.0022968045617495127
# 131 9
#
# Val set: Average loss: 1.4499, Accuracy: 101/131 (77%)
#
# 2444 153
# Train Epoch: 58 [160/2444 (7%)]	Loss: 0.000348
# Train Epoch: 58 [320/2444 (13%)]	Loss: 0.000078
# Train Epoch: 58 [480/2444 (20%)]	Loss: 0.000176
# Train Epoch: 58 [640/2444 (26%)]	Loss: 0.000217
# Train Epoch: 58 [800/2444 (33%)]	Loss: 0.000489
# Train Epoch: 58 [960/2444 (39%)]	Loss: 0.000420
# Train Epoch: 58 [1120/2444 (46%)]	Loss: 0.000030
# Train Epoch: 58 [1280/2444 (52%)]	Loss: 0.000100
# Train Epoch: 58 [1440/2444 (59%)]	Loss: 0.000160
# Train Epoch: 58 [1600/2444 (65%)]	Loss: 0.000402
# Train Epoch: 58 [1760/2444 (72%)]	Loss: 0.000191
# Train Epoch: 58 [1920/2444 (78%)]	Loss: 0.001308
# Train Epoch: 58 [2080/2444 (85%)]	Loss: 0.000008
# ...
# epoch:81,loss:0.023929069882785304
# 131 9
#
# Val set: Average loss: 1.5534, Accuracy: 102/131 (78%)
#
# 2444 153
# Train Epoch: 82 [160/2444 (7%)]	Loss: 0.000161
# Train Epoch: 82 [320/2444 (13%)]	Loss: 0.000429
# Train Epoch: 82 [480/2444 (20%)]	Loss: 0.000189
# Train Epoch: 82 [640/2444 (26%)]	Loss: 0.005907
# Train Epoch: 82 [800/2444 (33%)]	Loss: 0.000054
# Train Epoch: 82 [960/2444 (39%)]	Loss: 0.011070
# Train Epoch: 82 [1120/2444 (46%)]	Loss: 0.000306
# Train Epoch: 82 [1280/2444 (52%)]	Loss: 0.029926
# Train Epoch: 82 [1440/2444 (59%)]	Loss: 0.000959
# Train Epoch: 82 [1600/2444 (65%)]	Loss: 0.000017
# Train Epoch: 82 [1760/2444 (72%)]	Loss: 0.001180
# Train Epoch: 82 [1920/2444 (78%)]	Loss: 0.059445
# Train Epoch: 82 [2080/2444 (85%)]	Loss: 0.000492
# Train Epoch: 82 [2240/2444 (92%)]	Loss: 0.002466
# Train Epoch: 82 [2400/2444 (98%)]	Loss: 0.001026
# epoch:82,loss:0.02192512126483504
# 131 9
#
# Val set: Average loss: 1.7726, Accuracy: 101/131 (77%)
#
# 2444 153
# Train Epoch: 83 [160/2444 (7%)]	Loss: 0.008546
# Train Epoch: 83 [320/2444 (13%)]	Loss: 0.000426
# Train Epoch: 83 [480/2444 (20%)]	Loss: 0.007400
# Train Epoch: 83 [640/2444 (26%)]	Loss: 0.005401
# Train Epoch: 83 [800/2444 (33%)]	Loss: 0.159477
# Train Epoch: 83 [960/2444 (39%)]	Loss: 0.002061
# Train Epoch: 83 [1120/2444 (46%)]	Loss: 0.002947
# Train Epoch: 83 [1280/2444 (52%)]	Loss: 0.065779
# Train Epoch: 83 [1440/2444 (59%)]	Loss: 0.401917
# Train Epoch: 83 [1600/2444 (65%)]	Loss: 0.018693
# Train Epoch: 83 [1760/2444 (72%)]	Loss: 0.246476
# Train Epoch: 83 [1920/2444 (78%)]	Loss: 0.940343
# Train Epoch: 83 [2080/2444 (85%)]	Loss: 0.008257
# Train Epoch: 83 [2240/2444 (92%)]	Loss: 0.002717
# Train Epoch: 83 [2400/2444 (98%)]	Loss: 0.312375
# epoch:83,loss:0.10679023584344025
# 131 9
#
# Val set: Average loss: 1.6990, Accuracy: 100/131 (76%)
#
# 2444 153
# Train Epoch: 84 [160/2444 (7%)]	Loss: 0.154234
# Train Epoch: 84 [320/2444 (13%)]	Loss: 0.001928
# Train Epoch: 84 [480/2444 (20%)]	Loss: 0.150357
# Train Epoch: 84 [640/2444 (26%)]	Loss: 0.001992
# Train Epoch: 84 [800/2444 (33%)]	Loss: 0.025016
# Train Epoch: 84 [960/2444 (39%)]	Loss: 0.097087
# Train Epoch: 84 [1120/2444 (46%)]	Loss: 0.214470
# Train Epoch: 84 [1280/2444 (52%)]	Loss: 0.017337
# Train Epoch: 84 [1440/2444 (59%)]	Loss: 0.014902
# Train Epoch: 84 [1600/2444 (65%)]	Loss: 0.010059
# Train Epoch: 84 [1760/2444 (72%)]	Loss: 0.000304
# Train Epoch: 84 [1920/2444 (78%)]	Loss: 0.002040
# Train Epoch: 84 [2080/2444 (85%)]	Loss: 0.000262
# Train Epoch: 84 [2240/2444 (92%)]	Loss: 0.027104
# Train Epoch: 84 [2400/2444 (98%)]	Loss: 0.474921
# epoch:84,loss:0.08813039669597725
# 131 9
#
# Val set: Average loss: 1.7395, Accuracy: 95/131 (73%)
#
# 2444 153
# Train Epoch: 85 [160/2444 (7%)]	Loss: 0.069175
# Train Epoch: 85 [320/2444 (13%)]	Loss: 0.000492
# Train Epoch: 85 [480/2444 (20%)]	Loss: 0.029238
# Train Epoch: 85 [640/2444 (26%)]	Loss: 0.076013
# Train Epoch: 85 [800/2444 (33%)]	Loss: 0.004081
# Train Epoch: 85 [960/2444 (39%)]	Loss: 0.068022
# Train Epoch: 85 [1120/2444 (46%)]	Loss: 0.003355
# Train Epoch: 85 [1280/2444 (52%)]	Loss: 0.000848
# Train Epoch: 85 [1440/2444 (59%)]	Loss: 0.000547
# Train Epoch: 85 [1600/2444 (65%)]	Loss: 0.000439
# Train Epoch: 85 [1760/2444 (72%)]	Loss: 0.008337
# Train Epoch: 85 [1920/2444 (78%)]	Loss: 0.001802
# Train Epoch: 85 [2080/2444 (85%)]	Loss: 0.002628
# Train Epoch: 85 [2240/2444 (92%)]	Loss: 0.004044
# Train Epoch: 85 [2400/2444 (98%)]	Loss: 0.000145
# epoch:85,loss:0.027993525927146407
# 131 9
#
# Val set: Average loss: 1.5611, Accuracy: 97/131 (74%)
#
# 2444 153
# Train Epoch: 86 [160/2444 (7%)]	Loss: 0.037886
# Train Epoch: 86 [320/2444 (13%)]	Loss: 0.003347
# Train Epoch: 86 [480/2444 (20%)]	Loss: 0.000150
# Train Epoch: 86 [640/2444 (26%)]	Loss: 0.000073
# Train Epoch: 86 [800/2444 (33%)]	Loss: 0.000020
# Train Epoch: 86 [960/2444 (39%)]	Loss: 0.000211
# Train Epoch: 86 [1120/2444 (46%)]	Loss: 0.001774
# Train Epoch: 86 [1280/2444 (52%)]	Loss: 0.049219
# Train Epoch: 86 [1440/2444 (59%)]	Loss: 0.000093
# Train Epoch: 86 [1600/2444 (65%)]	Loss: 0.006991
# Train Epoch: 86 [1760/2444 (72%)]	Loss: 0.000365
# Train Epoch: 86 [1920/2444 (78%)]	Loss: 0.002932
# Train Epoch: 86 [2080/2444 (85%)]	Loss: 0.017347
# Train Epoch: 86 [2240/2444 (92%)]	Loss: 0.002407
# Train Epoch: 86 [2400/2444 (98%)]	Loss: 0.000021
# epoch:86,loss:0.017283009898243655
# 131 9
#
# Val set: Average loss: 1.6027, Accuracy: 98/131 (75%)
#
# 2444 153
# Train Epoch: 87 [160/2444 (7%)]	Loss: 0.000096
# Train Epoch: 87 [320/2444 (13%)]	Loss: 0.000066
# Train Epoch: 87 [480/2444 (20%)]	Loss: 0.002731
# Train Epoch: 87 [640/2444 (26%)]	Loss: 0.000199
# Train Epoch: 87 [800/2444 (33%)]	Loss: 0.000521
# Train Epoch: 87 [960/2444 (39%)]	Loss: 0.000333
# Train Epoch: 87 [1120/2444 (46%)]	Loss: 0.000295
# Train Epoch: 87 [1280/2444 (52%)]	Loss: 0.000118
# Train Epoch: 87 [1440/2444 (59%)]	Loss: 0.348967
# Train Epoch: 87 [1600/2444 (65%)]	Loss: 0.003941
# Train Epoch: 87 [1760/2444 (72%)]	Loss: 0.001288
# Train Epoch: 87 [1920/2444 (78%)]	Loss: 0.034198
# Train Epoch: 87 [2080/2444 (85%)]	Loss: 0.193466
# Train Epoch: 87 [2240/2444 (92%)]	Loss: 0.001190
# Train Epoch: 87 [2400/2444 (98%)]	Loss: 0.000302
# epoch:87,loss:0.02030043615459541
# 131 9
#
# Val set: Average loss: 1.2887, Accuracy: 102/131 (78%)
#
# 2444 153
# Train Epoch: 88 [160/2444 (7%)]	Loss: 0.290517
# Train Epoch: 88 [320/2444 (13%)]	Loss: 0.000040
# Train Epoch: 88 [480/2444 (20%)]	Loss: 0.000630
# Train Epoch: 88 [640/2444 (26%)]	Loss: 0.000102
# Train Epoch: 88 [800/2444 (33%)]	Loss: 0.003528
# Train Epoch: 88 [960/2444 (39%)]	Loss: 0.001559
# Train Epoch: 88 [1120/2444 (46%)]	Loss: 0.000962
# Train Epoch: 88 [1280/2444 (52%)]	Loss: 0.000004
# Train Epoch: 88 [1440/2444 (59%)]	Loss: 0.000017
# Train Epoch: 88 [1600/2444 (65%)]	Loss: 0.000097
# Train Epoch: 88 [1760/2444 (72%)]	Loss: 0.000017
# Train Epoch: 88 [1920/2444 (78%)]	Loss: 0.000080
# Train Epoch: 88 [2080/2444 (85%)]	Loss: 0.000254
# Train Epoch: 88 [2240/2444 (92%)]	Loss: 0.000086
# Train Epoch: 88 [2400/2444 (98%)]	Loss: 0.000158
# epoch:88,loss:0.01120715340618006
# 131 9
#
# Val set: Average loss: 1.6775, Accuracy: 98/131 (75%)
#
# 2444 153
# Train Epoch: 89 [160/2444 (7%)]	Loss: 0.031309
# Train Epoch: 89 [320/2444 (13%)]	Loss: 0.000551
# Train Epoch: 89 [480/2444 (20%)]	Loss: 0.002903
# Train Epoch: 89 [640/2444 (26%)]	Loss: 0.000374
# Train Epoch: 89 [800/2444 (33%)]	Loss: 0.000027
# Train Epoch: 89 [960/2444 (39%)]	Loss: 0.065108
# Train Epoch: 89 [1120/2444 (46%)]	Loss: 0.001778
# Train Epoch: 89 [1280/2444 (52%)]	Loss: 0.000126
# Train Epoch: 89 [1440/2444 (59%)]	Loss: 0.000058
# Train Epoch: 89 [1600/2444 (65%)]	Loss: 0.000424
# Train Epoch: 89 [1760/2444 (72%)]	Loss: 0.000214
# Train Epoch: 89 [1920/2444 (78%)]	Loss: 0.000014
# Train Epoch: 89 [2080/2444 (85%)]	Loss: 0.002998
# Train Epoch: 89 [2240/2444 (92%)]	Loss: 0.002043
# Train Epoch: 89 [2400/2444 (98%)]	Loss: 0.113542
# epoch:89,loss:0.01658299505715405
# 131 9
#
# Val set: Average loss: 1.5091, Accuracy: 98/131 (75%)
#
# 2444 153
# Train Epoch: 90 [160/2444 (7%)]	Loss: 0.000129
# Train Epoch: 90 [320/2444 (13%)]	Loss: 0.000052
# Train Epoch: 90 [480/2444 (20%)]	Loss: 0.000128
# Train Epoch: 90 [640/2444 (26%)]	Loss: 0.000133
# Train Epoch: 90 [800/2444 (33%)]	Loss: 0.000137
# Train Epoch: 90 [960/2444 (39%)]	Loss: 0.000098
# Train Epoch: 90 [1120/2444 (46%)]	Loss: 0.000195
# Train Epoch: 90 [1280/2444 (52%)]	Loss: 0.194054
# Train Epoch: 90 [1440/2444 (59%)]	Loss: 0.000029
# Train Epoch: 90 [1600/2444 (65%)]	Loss: 0.179566
# Train Epoch: 90 [1760/2444 (72%)]	Loss: 0.001353
# Train Epoch: 90 [1920/2444 (78%)]	Loss: 0.000307
# Train Epoch: 90 [2080/2444 (85%)]	Loss: 0.087604
# Train Epoch: 90 [2240/2444 (92%)]	Loss: 0.000073
# Train Epoch: 90 [2400/2444 (98%)]	Loss: 0.000413
# epoch:90,loss:0.013261007699660623
# 131 9
#
# Val set: Average loss: 1.4487, Accuracy: 99/131 (76%)
#
# 2444 153
# Train Epoch: 91 [160/2444 (7%)]	Loss: 0.000112
# Train Epoch: 91 [320/2444 (13%)]	Loss: 0.000011
# Train Epoch: 91 [480/2444 (20%)]	Loss: 0.036810
# Train Epoch: 91 [640/2444 (26%)]	Loss: 0.612985
# Train Epoch: 91 [800/2444 (33%)]	Loss: 0.000808
# Train Epoch: 91 [960/2444 (39%)]	Loss: 0.000250
# Train Epoch: 91 [1120/2444 (46%)]	Loss: 0.000170
# Train Epoch: 91 [1280/2444 (52%)]	Loss: 0.000014
# Train Epoch: 91 [1440/2444 (59%)]	Loss: 0.000043
# Train Epoch: 91 [1600/2444 (65%)]	Loss: 0.003520
# Train Epoch: 91 [1760/2444 (72%)]	Loss: 0.000345
# Train Epoch: 91 [1920/2444 (78%)]	Loss: 0.002788
# Train Epoch: 91 [2080/2444 (85%)]	Loss: 0.001246
# Train Epoch: 91 [2240/2444 (92%)]	Loss: 0.006780
# Train Epoch: 91 [2400/2444 (98%)]	Loss: 0.076324
# epoch:91,loss:0.016016619421998553
# 131 9
#
# Val set: Average loss: 1.7472, Accuracy: 102/131 (78%)
#
# 2444 153
# Train Epoch: 92 [160/2444 (7%)]	Loss: 0.029997
# Train Epoch: 92 [320/2444 (13%)]	Loss: 0.000013
# Train Epoch: 92 [480/2444 (20%)]	Loss: 0.000026
# Train Epoch: 92 [640/2444 (26%)]	Loss: 0.015182
# Train Epoch: 92 [800/2444 (33%)]	Loss: 0.000247
# Train Epoch: 92 [960/2444 (39%)]	Loss: 0.000178
# Train Epoch: 92 [1120/2444 (46%)]	Loss: 0.000089
# Train Epoch: 92 [1280/2444 (52%)]	Loss: 0.049437
# Train Epoch: 92 [1440/2444 (59%)]	Loss: 0.000009
# Train Epoch: 92 [1600/2444 (65%)]	Loss: 0.000054
# Train Epoch: 92 [1760/2444 (72%)]	Loss: 0.000486
# Train Epoch: 92 [1920/2444 (78%)]	Loss: 0.000085
# Train Epoch: 92 [2080/2444 (85%)]	Loss: 0.002934
# Train Epoch: 92 [2240/2444 (92%)]	Loss: 0.000150
# Train Epoch: 92 [2400/2444 (98%)]	Loss: 0.000017
# epoch:92,loss:0.00638202434496414
# 131 9
#
# Val set: Average loss: 1.3856, Accuracy: 98/131 (75%)
#
# 2444 153
# Train Epoch: 93 [160/2444 (7%)]	Loss: 0.002088
# Train Epoch: 93 [320/2444 (13%)]	Loss: 0.003626
# Train Epoch: 93 [480/2444 (20%)]	Loss: 0.000011
# Train Epoch: 93 [640/2444 (26%)]	Loss: 0.000013
# Train Epoch: 93 [800/2444 (33%)]	Loss: 0.010715
# Train Epoch: 93 [960/2444 (39%)]	Loss: 0.000001
# Train Epoch: 93 [1120/2444 (46%)]	Loss: 0.000001
# Train Epoch: 93 [1280/2444 (52%)]	Loss: 0.000039
# Train Epoch: 93 [1440/2444 (59%)]	Loss: 0.000028
# Train Epoch: 93 [1600/2444 (65%)]	Loss: 0.000022
# Train Epoch: 93 [1760/2444 (72%)]	Loss: 0.001081
# Train Epoch: 93 [1920/2444 (78%)]	Loss: 0.000010
# Train Epoch: 93 [2080/2444 (85%)]	Loss: 0.000015
# Train Epoch: 93 [2240/2444 (92%)]	Loss: 0.000098
# Train Epoch: 93 [2400/2444 (98%)]	Loss: 0.000083
# epoch:93,loss:0.004610509180974021
# 131 9
#
# Val set: Average loss: 1.7264, Accuracy: 96/131 (73%)
#
# 2444 153
# Train Epoch: 94 [160/2444 (7%)]	Loss: 0.001730
# Train Epoch: 94 [320/2444 (13%)]	Loss: 0.000394
# Train Epoch: 94 [480/2444 (20%)]	Loss: 0.000067
# Train Epoch: 94 [640/2444 (26%)]	Loss: 0.000024
# Train Epoch: 94 [800/2444 (33%)]	Loss: 0.000022
# Train Epoch: 94 [960/2444 (39%)]	Loss: 0.000009
# Train Epoch: 94 [1120/2444 (46%)]	Loss: 0.000922
# Train Epoch: 94 [1280/2444 (52%)]	Loss: 0.001513
# Train Epoch: 94 [1440/2444 (59%)]	Loss: 0.000006
# Train Epoch: 94 [1600/2444 (65%)]	Loss: 0.000013
# Train Epoch: 94 [1760/2444 (72%)]	Loss: 0.000135
# Train Epoch: 94 [1920/2444 (78%)]	Loss: 0.000045
# Train Epoch: 94 [2080/2444 (85%)]	Loss: 0.000043
# Train Epoch: 94 [2240/2444 (92%)]	Loss: 0.000219
# Train Epoch: 94 [2400/2444 (98%)]	Loss: 0.004000
# epoch:94,loss:0.0035073065003846044
# 131 9
#
# Val set: Average loss: 1.3683, Accuracy: 102/131 (78%)
#
# 2444 153
# Train Epoch: 95 [160/2444 (7%)]	Loss: 0.000147
# Train Epoch: 95 [320/2444 (13%)]	Loss: 0.000019
# Train Epoch: 95 [480/2444 (20%)]	Loss: 0.000067
# Train Epoch: 95 [640/2444 (26%)]	Loss: 0.000389
# Train Epoch: 95 [800/2444 (33%)]	Loss: 0.000011
# Train Epoch: 95 [960/2444 (39%)]	Loss: 0.000023
# Train Epoch: 95 [1120/2444 (46%)]	Loss: 0.000009
# Train Epoch: 95 [1280/2444 (52%)]	Loss: 0.103613
# Train Epoch: 95 [1440/2444 (59%)]	Loss: 0.000057
# Train Epoch: 95 [1600/2444 (65%)]	Loss: 0.000025
# Train Epoch: 95 [1760/2444 (72%)]	Loss: 0.000018
# Train Epoch: 95 [1920/2444 (78%)]	Loss: 0.000162
# Train Epoch: 95 [2080/2444 (85%)]	Loss: 0.000079
# Train Epoch: 95 [2240/2444 (92%)]	Loss: 0.000007
# Train Epoch: 95 [2400/2444 (98%)]	Loss: 0.000216
# epoch:95,loss:0.0023836120500777577
# 131 9
#
# Val set: Average loss: 1.3327, Accuracy: 102/131 (78%)
#
# 2444 153
# Train Epoch: 96 [160/2444 (7%)]	Loss: 0.002899
# Train Epoch: 96 [320/2444 (13%)]	Loss: 0.000017
# Train Epoch: 96 [480/2444 (20%)]	Loss: 0.000011
# Train Epoch: 96 [640/2444 (26%)]	Loss: 0.000099
# Train Epoch: 96 [800/2444 (33%)]	Loss: 0.000375
# Train Epoch: 96 [960/2444 (39%)]	Loss: 0.000164
# Train Epoch: 96 [1120/2444 (46%)]	Loss: 0.000020
# Train Epoch: 96 [1280/2444 (52%)]	Loss: 0.000053
# Train Epoch: 96 [1440/2444 (59%)]	Loss: 0.000035
# Train Epoch: 96 [1600/2444 (65%)]	Loss: 0.000033
# Train Epoch: 96 [1760/2444 (72%)]	Loss: 0.000143
# Train Epoch: 96 [1920/2444 (78%)]	Loss: 0.000015
# Train Epoch: 96 [2080/2444 (85%)]	Loss: 0.000068
# Train Epoch: 96 [2240/2444 (92%)]	Loss: 0.000005
# Train Epoch: 96 [2400/2444 (98%)]	Loss: 0.000023
# epoch:96,loss:0.003914918901588321
# 131 9
#
# Val set: Average loss: 1.2619, Accuracy: 102/131 (78%)
#
# 2444 153
# Train Epoch: 97 [160/2444 (7%)]	Loss: 0.000004
# Train Epoch: 97 [320/2444 (13%)]	Loss: 0.000074
# Train Epoch: 97 [480/2444 (20%)]	Loss: 0.000076
# Train Epoch: 97 [640/2444 (26%)]	Loss: 0.000059
# Train Epoch: 97 [800/2444 (33%)]	Loss: 0.000252
# Train Epoch: 97 [960/2444 (39%)]	Loss: 0.000017
# Train Epoch: 97 [1120/2444 (46%)]	Loss: 0.000028
# Train Epoch: 97 [1280/2444 (52%)]	Loss: 0.000023
# Train Epoch: 97 [1440/2444 (59%)]	Loss: 0.000146
# Train Epoch: 97 [1600/2444 (65%)]	Loss: 0.000039
# Train Epoch: 97 [1760/2444 (72%)]	Loss: 0.000021
# Train Epoch: 97 [1920/2444 (78%)]	Loss: 0.000009
# Train Epoch: 97 [2080/2444 (85%)]	Loss: 0.000019
# Train Epoch: 97 [2240/2444 (92%)]	Loss: 0.000004
# Train Epoch: 97 [2400/2444 (98%)]	Loss: 0.000030
# epoch:97,loss:0.001781542580127969
# 131 9
#
# Val set: Average loss: 1.1727, Accuracy: 99/131 (76%)
#
# 2444 153
# Train Epoch: 98 [160/2444 (7%)]	Loss: 0.000027
# Train Epoch: 98 [320/2444 (13%)]	Loss: 0.000084
# Train Epoch: 98 [480/2444 (20%)]	Loss: 0.000089
# Train Epoch: 98 [640/2444 (26%)]	Loss: 0.000295
# Train Epoch: 98 [800/2444 (33%)]	Loss: 0.000422
# Train Epoch: 98 [960/2444 (39%)]	Loss: 0.001519
# Train Epoch: 98 [1120/2444 (46%)]	Loss: 0.000034
# Train Epoch: 98 [1280/2444 (52%)]	Loss: 0.000476
# Train Epoch: 98 [1440/2444 (59%)]	Loss: 0.000438
# Train Epoch: 98 [1600/2444 (65%)]	Loss: 0.000676
# Train Epoch: 98 [1760/2444 (72%)]	Loss: 0.000020
# Train Epoch: 98 [1920/2444 (78%)]	Loss: 0.059927
# Train Epoch: 98 [2080/2444 (85%)]	Loss: 0.000041
# Train Epoch: 98 [2240/2444 (92%)]	Loss: 0.000039
# Train Epoch: 98 [2400/2444 (98%)]	Loss: 0.000008
# epoch:98,loss:0.001639829236296464
# 131 9
#
# Val set: Average loss: 1.2303, Accuracy: 102/131 (78%)
#
# 2444 153
# Train Epoch: 99 [160/2444 (7%)]	Loss: 0.000014
# Train Epoch: 99 [320/2444 (13%)]	Loss: 0.000026
# Train Epoch: 99 [480/2444 (20%)]	Loss: 0.000129
# Train Epoch: 99 [640/2444 (26%)]	Loss: 0.000051
# Train Epoch: 99 [800/2444 (33%)]	Loss: 0.115973
# Train Epoch: 99 [960/2444 (39%)]	Loss: 0.000112
# Train Epoch: 99 [1120/2444 (46%)]	Loss: 0.000168
# Train Epoch: 99 [1280/2444 (52%)]	Loss: 0.000462
# Train Epoch: 99 [1440/2444 (59%)]	Loss: 0.000165
# Train Epoch: 99 [1600/2444 (65%)]	Loss: 0.000058
# Train Epoch: 99 [1760/2444 (72%)]	Loss: 0.000025
# Train Epoch: 99 [1920/2444 (78%)]	Loss: 0.000745
# Train Epoch: 99 [2080/2444 (85%)]	Loss: 0.000013
# Train Epoch: 99 [2240/2444 (92%)]	Loss: 0.000895
# Train Epoch: 99 [2400/2444 (98%)]	Loss: 0.000058
# epoch:99,loss:0.003648822476258466
# 131 9
#
# Val set: Average loss: 1.2151, Accuracy: 100/131 (76%)
#
# 2444 153
# Train Epoch: 100 [160/2444 (7%)]	Loss: 0.000016
# Train Epoch: 100 [320/2444 (13%)]	Loss: 0.000099
# Train Epoch: 100 [480/2444 (20%)]	Loss: 0.000019
# Train Epoch: 100 [640/2444 (26%)]	Loss: 0.000039
# Train Epoch: 100 [800/2444 (33%)]	Loss: 0.000012
# Train Epoch: 100 [960/2444 (39%)]	Loss: 0.000001
# Train Epoch: 100 [1120/2444 (46%)]	Loss: 0.000017
# Train Epoch: 100 [1280/2444 (52%)]	Loss: 0.000086
# Train Epoch: 100 [1440/2444 (59%)]	Loss: 0.000008
# Train Epoch: 100 [1600/2444 (65%)]	Loss: 0.001290
# Train Epoch: 100 [1760/2444 (72%)]	Loss: 0.000042
# Train Epoch: 100 [1920/2444 (78%)]	Loss: 0.000018
# Train Epoch: 100 [2080/2444 (85%)]	Loss: 0.000051
# Train Epoch: 100 [2240/2444 (92%)]	Loss: 0.000007
# Train Epoch: 100 [2400/2444 (98%)]	Loss: 0.000009
# epoch:100,loss:0.0021575111467133385
# 131 9
#
# Val set: Average loss: 1.2173, Accuracy: 102/131 (78%)

# %%
torch.save(model_ft, 'model.pth')

# %% [markdown]
# Test

# %%
classes = (
     'daisy', 'dandelion', 'rose', 'sunflower', 'tulip'
)
     
transform_test = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])
])

# %%
#load the model and put model in DEVICE
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = torch.load("model.pth")
model.eval()
model.to(DEVICE)
# Out:
# CoAtNet(
#   (s0): Sequential(
#     (0): Sequential(
#       (0): Conv2d(3, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): GELU(approximate=none)
#     )
#     (1): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): GELU(approximate=none)
#     )
#   )
#   (s1): Sequential(
#     (0): MBConv(
#       (pool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (proj): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (conv): PreNorm(
#         (norm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (fn): Sequential(
#           (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): GELU(approximate=none)
#           (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#           (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): GELU(approximate=none)
#           (6): SE(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=512, out_features=32, bias=False)
#               (1): GELU(approximate=none)
#               (2): Linear(in_features=32, out_features=512, bias=False)
#               (3): Sigmoid()
#             )
#           )
#           (7): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (1): MBConv(
#       (conv): PreNorm(
#         (norm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (fn): Sequential(
#           (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): GELU(approximate=none)
#           (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#           (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): GELU(approximate=none)
#           (6): SE(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=512, out_features=32, bias=False)
#               (1): GELU(approximate=none)
#               (2): Linear(in_features=32, out_features=512, bias=False)
#               (3): Sigmoid()
#             )
#           )
#           (7): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#   )
#   (s2): Sequential(
#     (0): MBConv(
#       (pool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (proj): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (conv): PreNorm(
#         (norm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (fn): Sequential(
#           (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): GELU(approximate=none)
#           (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#           (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): GELU(approximate=none)
#           (6): SE(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=512, out_features=32, bias=False)
#               (1): GELU(approximate=none)
#               (2): Linear(in_features=32, out_features=512, bias=False)
#               (3): Sigmoid()
#             )
#           )
#           (7): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (8): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (1): MBConv(
#       (conv): PreNorm(
#         (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (fn): Sequential(
#           (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): GELU(approximate=none)
#           (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024, bias=False)
#           (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): GELU(approximate=none)
#           (6): SE(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=1024, out_features=64, bias=False)
#               (1): GELU(approximate=none)
#               (2): Linear(in_features=64, out_features=1024, bias=False)
#               (3): Sigmoid()
#             )
#           )
#           (7): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (8): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (2): MBConv(
#       (conv): PreNorm(
#         (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (fn): Sequential(
#           (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): GELU(approximate=none)
#           (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024, bias=False)
#           (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): GELU(approximate=none)
#           (6): SE(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=1024, out_features=64, bias=False)
#               (1): GELU(approximate=none)
#               (2): Linear(in_features=64, out_features=1024, bias=False)
#               (3): Sigmoid()
#             )
#           )
#           (7): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (8): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (3): MBConv(
#       (conv): PreNorm(
#         (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (fn): Sequential(
#           (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): GELU(approximate=none)
#           (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024, bias=False)
#           (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): GELU(approximate=none)
#           (6): SE(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=1024, out_features=64, bias=False)
#               (1): GELU(approximate=none)
#               (2): Linear(in_features=64, out_features=1024, bias=False)
#               (3): Sigmoid()
#             )
#           )
#           (7): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (8): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (4): MBConv(
#       (conv): PreNorm(
#         (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (fn): Sequential(
#           (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): GELU(approximate=none)
#           (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024, bias=False)
#           (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): GELU(approximate=none)
#           (6): SE(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=1024, out_features=64, bias=False)
#               (1): GELU(approximate=none)
#               (2): Linear(in_features=64, out_features=1024, bias=False)
#               (3): Sigmoid()
#             )
#           )
#           (7): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (8): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (5): MBConv(
#       (conv): PreNorm(
#         (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (fn): Sequential(
#           (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): GELU(approximate=none)
#           (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024, bias=False)
#           (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): GELU(approximate=none)
#           (6): SE(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=1024, out_features=64, bias=False)
#               (1): GELU(approximate=none)
#               (2): Linear(in_features=64, out_features=1024, bias=False)
#               (3): Sigmoid()
#             )
#           )
#           (7): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (8): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#   )
#   (s3): Sequential(
#     (0): Transformer(
#       (pool1): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (pool2): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (proj): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (attn): Sequential(
#         (0): Rearrange('b c ih iw -> b (ih iw) c')
#         (1): PreNorm(
#           (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (fn): Attention(
#             (attend): Softmax(dim=-1)
#             (to_qkv): Linear(in_features=256, out_features=768, bias=False)
#             (to_out): Sequential(
#               (0): Linear(in_features=256, out_features=512, bias=True)
#               (1): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#         (2): Rearrange('b (ih iw) c -> b c ih iw', ih=14, iw=14)
#       )
#       (ff): Sequential(
#         (0): Rearrange('b c ih iw -> b (ih iw) c')
#         (1): PreNorm(
#           (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (fn): FeedForward(
#             (net): Sequential(
#               (0): Linear(in_features=512, out_features=1024, bias=True)
#               (1): GELU(approximate=none)
#               (2): Dropout(p=0.0, inplace=False)
#               (3): Linear(in_features=1024, out_features=512, bias=True)
#               (4): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#         (2): Rearrange('b (ih iw) c -> b c ih iw', ih=14, iw=14)
#       )
#     )
#     (1): Transformer(
#       (attn): Sequential(
#         (0): Rearrange('b c ih iw -> b (ih iw) c')
#         (1): PreNorm(
#           (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (fn): Attention(
#             (attend): Softmax(dim=-1)
#             (to_qkv): Linear(in_features=512, out_features=768, bias=False)
#             (to_out): Sequential(
#               (0): Linear(in_features=256, out_features=512, bias=True)
#               (1): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#         (2): Rearrange('b (ih iw) c -> b c ih iw', ih=14, iw=14)
#       )
#       (ff): Sequential(
#         (0): Rearrange('b c ih iw -> b (ih iw) c')
#         (1): PreNorm(
#           (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (fn): FeedForward(
#             (net): Sequential(
#               (0): Linear(in_features=512, out_features=2048, bias=True)
#               (1): GELU(approximate=none)
#               (2): Dropout(p=0.0, inplace=False)
#               (3): Linear(in_features=2048, out_features=512, bias=True)
#               (4): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#         (2): Rearrange('b (ih iw) c -> b c ih iw', ih=14, iw=14)
#       )
#     )
#     (2): Transformer(
#       (attn): Sequential(
#         (0): Rearrange('b c ih iw -> b (ih iw) c')
#         (1): PreNorm(
#           (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (fn): Attention(
#             (attend): Softmax(dim=-1)
#             (to_qkv): Linear(in_features=512, out_features=768, bias=False)
#             (to_out): Sequential(
#               (0): Linear(in_features=256, out_features=512, bias=True)
#               (1): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#         (2): Rearrange('b (ih iw) c -> b c ih iw', ih=14, iw=14)
#       )
#       (ff): Sequential(
#         (0): Rearrange('b c ih iw -> b (ih iw) c')
#         (1): PreNorm(
#           (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (fn): FeedForward(
#             (net): Sequential(
#               (0): Linear(in_features=512, out_features=2048, bias=True)
#               (1): GELU(approximate=none)
#               (2): Dropout(p=0.0, inplace=False)
#               (3): Linear(in_features=2048, out_features=512, bias=True)
#               (4): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#         (2): Rearrange('b (ih iw) c -> b c ih iw', ih=14, iw=14)
#       )
#     )
#     (3): Transformer(
#       (attn): Sequential(
#         (0): Rearrange('b c ih iw -> b (ih iw) c')
#         (1): PreNorm(
#           (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (fn): Attention(
#             (attend): Softmax(dim=-1)
#             (to_qkv): Linear(in_features=512, out_features=768, bias=False)
#             (to_out): Sequential(
#               (0): Linear(in_features=256, out_features=512, bias=True)
#               (1): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#         (2): Rearrange('b (ih iw) c -> b c ih iw', ih=14, iw=14)
#       )
#       (ff): Sequential(
#         (0): Rearrange('b c ih iw -> b (ih iw) c')
#         (1): PreNorm(
#           (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (fn): FeedForward(
#             (net): Sequential(
#               (0): Linear(in_features=512, out_features=2048, bias=True)
#               (1): GELU(approximate=none)
#               (2): Dropout(p=0.0, inplace=False)
#               (3): Linear(in_features=2048, out_features=512, bias=True)
#               (4): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#         (2): Rearrange('b (ih iw) c -> b c ih iw', ih=14, iw=14)
#       )
#     )
#     (4): Transformer(
#       (attn): Sequential(
#         (0): Rearrange('b c ih iw -> b (ih iw) c')
#         (1): PreNorm(
#           (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (fn): Attention(
#             (attend): Softmax(dim=-1)
#             (to_qkv): Linear(in_features=512, out_features=768, bias=False)
#             (to_out): Sequential(
#               (0): Linear(in_features=256, out_features=512, bias=True)
#               (1): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#         (2): Rearrange('b (ih iw) c -> b c ih iw', ih=14, iw=14)
#       )
#       (ff): Sequential(
#         (0): Rearrange('b c ih iw -> b (ih iw) c')
#         (1): PreNorm(
#           (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (fn): FeedForward(
#             (net): Sequential(
#               (0): Linear(in_features=512, out_features=2048, bias=True)
#               (1): GELU(approximate=none)
#               (2): Dropout(p=0.0, inplace=False)
#               (3): Linear(in_features=2048, out_features=512, bias=True)
#               (4): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#         (2): Rearrange('b (ih iw) c -> b c ih iw', ih=14, iw=14)
#       )
#     )
#     (5): Transformer(
#       (attn): Sequential(
#         (0): Rearrange('b c ih iw -> b (ih iw) c')
#         (1): PreNorm(
#           (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (fn): Attention(
#             (attend): Softmax(dim=-1)
#             (to_qkv): Linear(in_features=512, out_features=768, bias=False)
#             (to_out): Sequential(
#               (0): Linear(in_features=256, out_features=512, bias=True)
#               (1): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#         (2): Rearrange('b (ih iw) c -> b c ih iw', ih=14, iw=14)
#       )
#       (ff): Sequential(
#         (0): Rearrange('b c ih iw -> b (ih iw) c')
#         (1): PreNorm(
#           (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (fn): FeedForward(
#             (net): Sequential(
#               (0): Linear(in_features=512, out_features=2048, bias=True)
#               (1): GELU(approximate=none)
#               (2): Dropout(p=0.0, inplace=False)
#               (3): Linear(in_features=2048, out_features=512, bias=True)
#               (4): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#         (2): Rearrange('b (ih iw) c -> b c ih iw', ih=14, iw=14)
#       )
#     )
#     (6): Transformer(
#       (attn): Sequential(
#         (0): Rearrange('b c ih iw -> b (ih iw) c')
#         (1): PreNorm(
#           (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (fn): Attention(
#             (attend): Softmax(dim=-1)
#             (to_qkv): Linear(in_features=512, out_features=768, bias=False)
#             (to_out): Sequential(
#               (0): Linear(in_features=256, out_features=512, bias=True)
#               (1): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#         (2): Rearrange('b (ih iw) c -> b c ih iw', ih=14, iw=14)
#       )
#       (ff): Sequential(
#         (0): Rearrange('b c ih iw -> b (ih iw) c')
#         (1): PreNorm(
#           (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (fn): FeedForward(
#             (net): Sequential(
#               (0): Linear(in_features=512, out_features=2048, bias=True)
#               (1): GELU(approximate=none)
#               (2): Dropout(p=0.0, inplace=False)
#               (3): Linear(in_features=2048, out_features=512, bias=True)
#               (4): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#         (2): Rearrange('b (ih iw) c -> b c ih iw', ih=14, iw=14)
#       )
#     )
#     (7): Transformer(
#       (attn): Sequential(
#         (0): Rearrange('b c ih iw -> b (ih iw) c')
#         (1): PreNorm(
#           (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (fn): Attention(
#             (attend): Softmax(dim=-1)
#             (to_qkv): Linear(in_features=512, out_features=768, bias=False)
#             (to_out): Sequential(
#               (0): Linear(in_features=256, out_features=512, bias=True)
#               (1): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#         (2): Rearrange('b (ih iw) c -> b c ih iw', ih=14, iw=14)
#       )
#       (ff): Sequential(
#         (0): Rearrange('b c ih iw -> b (ih iw) c')
#         (1): PreNorm(
#           (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (fn): FeedForward(
#             (net): Sequential(
#               (0): Linear(in_features=512, out_features=2048, bias=True)
#               (1): GELU(approximate=none)
#               (2): Dropout(p=0.0, inplace=False)
#               (3): Linear(in_features=2048, out_features=512, bias=True)
#               (4): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#         (2): Rearrange('b (ih iw) c -> b c ih iw', ih=14, iw=14)
#       )
#     )
#     (8): Transformer(
#       (attn): Sequential(
#         (0): Rearrange('b c ih iw -> b (ih iw) c')
#         (1): PreNorm(
#           (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (fn): Attention(
#             (attend): Softmax(dim=-1)
#             (to_qkv): Linear(in_features=512, out_features=768, bias=False)
#             (to_out): Sequential(
#               (0): Linear(in_features=256, out_features=512, bias=True)
#               (1): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#         (2): Rearrange('b (ih iw) c -> b c ih iw', ih=14, iw=14)
#       )
#       (ff): Sequential(
#         (0): Rearrange('b c ih iw -> b (ih iw) c')
#         (1): PreNorm(
#           (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (fn): FeedForward(
#             (net): Sequential(
#               (0): Linear(in_features=512, out_features=2048, bias=True)
#               (1): GELU(approximate=none)
#               (2): Dropout(p=0.0, inplace=False)
#               (3): Linear(in_features=2048, out_features=512, bias=True)
#               (4): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#         (2): Rearrange('b (ih iw) c -> b c ih iw', ih=14, iw=14)
#       )
#     )
#     (9): Transformer(
#       (attn): Sequential(
#         (0): Rearrange('b c ih iw -> b (ih iw) c')
#         (1): PreNorm(
#           (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (fn): Attention(
#             (attend): Softmax(dim=-1)
#             (to_qkv): Linear(in_features=512, out_features=768, bias=False)
#             (to_out): Sequential(
#               (0): Linear(in_features=256, out_features=512, bias=True)
#               (1): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#         (2): Rearrange('b (ih iw) c -> b c ih iw', ih=14, iw=14)
#       )
#       (ff): Sequential(
#         (0): Rearrange('b c ih iw -> b (ih iw) c')
#         (1): PreNorm(
#           (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (fn): FeedForward(
#             (net): Sequential(
#               (0): Linear(in_features=512, out_features=2048, bias=True)
#               (1): GELU(approximate=none)
#               (2): Dropout(p=0.0, inplace=False)
#               (3): Linear(in_features=2048, out_features=512, bias=True)
#               (4): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#         (2): Rearrange('b (ih iw) c -> b c ih iw', ih=14, iw=14)
#       )
#     )
#     (10): Transformer(
#       (attn): Sequential(
#         (0): Rearrange('b c ih iw -> b (ih iw) c')
#         (1): PreNorm(
#           (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (fn): Attention(
#             (attend): Softmax(dim=-1)
#             (to_qkv): Linear(in_features=512, out_features=768, bias=False)
#             (to_out): Sequential(
#               (0): Linear(in_features=256, out_features=512, bias=True)
#               (1): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#         (2): Rearrange('b (ih iw) c -> b c ih iw', ih=14, iw=14)
#       )
#       (ff): Sequential(
#         (0): Rearrange('b c ih iw -> b (ih iw) c')
#         (1): PreNorm(
#           (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (fn): FeedForward(
#             (net): Sequential(
#               (0): Linear(in_features=512, out_features=2048, bias=True)
#               (1): GELU(approximate=none)
#               (2): Dropout(p=0.0, inplace=False)
#               (3): Linear(in_features=2048, out_features=512, bias=True)
#               (4): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#         (2): Rearrange('b (ih iw) c -> b c ih iw', ih=14, iw=14)
#       )
#     )
#     (11): Transformer(
#       (attn): Sequential(
#         (0): Rearrange('b c ih iw -> b (ih iw) c')
#         (1): PreNorm(
#           (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (fn): Attention(
#             (attend): Softmax(dim=-1)
#             (to_qkv): Linear(in_features=512, out_features=768, bias=False)
#             (to_out): Sequential(
#               (0): Linear(in_features=256, out_features=512, bias=True)
#               (1): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#         (2): Rearrange('b (ih iw) c -> b c ih iw', ih=14, iw=14)
#       )
#       (ff): Sequential(
#         (0): Rearrange('b c ih iw -> b (ih iw) c')
#         (1): PreNorm(
#           (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (fn): FeedForward(
#             (net): Sequential(
#               (0): Linear(in_features=512, out_features=2048, bias=True)
#               (1): GELU(approximate=none)
#               (2): Dropout(p=0.0, inplace=False)
#               (3): Linear(in_features=2048, out_features=512, bias=True)
#               (4): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#         (2): Rearrange('b (ih iw) c -> b c ih iw', ih=14, iw=14)
#       )
#     )
#     (12): Transformer(
#       (attn): Sequential(
#         (0): Rearrange('b c ih iw -> b (ih iw) c')
#         (1): PreNorm(
#           (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (fn): Attention(
#             (attend): Softmax(dim=-1)
#             (to_qkv): Linear(in_features=512, out_features=768, bias=False)
#             (to_out): Sequential(
#               (0): Linear(in_features=256, out_features=512, bias=True)
#               (1): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#         (2): Rearrange('b (ih iw) c -> b c ih iw', ih=14, iw=14)
#       )
#       (ff): Sequential(
#         (0): Rearrange('b c ih iw -> b (ih iw) c')
#         (1): PreNorm(
#           (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (fn): FeedForward(
#             (net): Sequential(
#               (0): Linear(in_features=512, out_features=2048, bias=True)
#               (1): GELU(approximate=none)
#               (2): Dropout(p=0.0, inplace=False)
#               (3): Linear(in_features=2048, out_features=512, bias=True)
#               (4): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#         (2): Rearrange('b (ih iw) c -> b c ih iw', ih=14, iw=14)
#       )
#     )
#     (13): Transformer(
#       (attn): Sequential(
#         (0): Rearrange('b c ih iw -> b (ih iw) c')
#         (1): PreNorm(
#           (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (fn): Attention(
#             (attend): Softmax(dim=-1)
#             (to_qkv): Linear(in_features=512, out_features=768, bias=False)
#             (to_out): Sequential(
#               (0): Linear(in_features=256, out_features=512, bias=True)
#               (1): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#         (2): Rearrange('b (ih iw) c -> b c ih iw', ih=14, iw=14)
#       )
#       (ff): Sequential(
#         (0): Rearrange('b c ih iw -> b (ih iw) c')
#         (1): PreNorm(
#           (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (fn): FeedForward(
#             (net): Sequential(
#               (0): Linear(in_features=512, out_features=2048, bias=True)
#               (1): GELU(approximate=none)
#               (2): Dropout(p=0.0, inplace=False)
#               (3): Linear(in_features=2048, out_features=512, bias=True)
#               (4): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#         (2): Rearrange('b (ih iw) c -> b c ih iw', ih=14, iw=14)
#       )
#     )
#   )
#   (s4): Sequential(
#     (0): Transformer(
#       (pool1): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (pool2): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (proj): Conv2d(512, 1026, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (attn): Sequential(
#         (0): Rearrange('b c ih iw -> b (ih iw) c')
#         (1): PreNorm(
#           (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (fn): Attention(
#             (attend): Softmax(dim=-1)
#             (to_qkv): Linear(in_features=512, out_features=768, bias=False)
#             (to_out): Sequential(
#               (0): Linear(in_features=256, out_features=1026, bias=True)
#               (1): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#         (2): Rearrange('b (ih iw) c -> b c ih iw', ih=7, iw=7)
#       )
#       (ff): Sequential(
#         (0): Rearrange('b c ih iw -> b (ih iw) c')
#         (1): PreNorm(
#           (norm): LayerNorm((1026,), eps=1e-05, elementwise_affine=True)
#           (fn): FeedForward(
#             (net): Sequential(
#               (0): Linear(in_features=1026, out_features=2048, bias=True)
#               (1): GELU(approximate=none)
#               (2): Dropout(p=0.0, inplace=False)
#               (3): Linear(in_features=2048, out_features=1026, bias=True)
#               (4): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#         (2): Rearrange('b (ih iw) c -> b c ih iw', ih=7, iw=7)
#       )
#     )
#     (1): Transformer(
#       (attn): Sequential(
#         (0): Rearrange('b c ih iw -> b (ih iw) c')
#         (1): PreNorm(
#           (norm): LayerNorm((1026,), eps=1e-05, elementwise_affine=True)
#           (fn): Attention(
#             (attend): Softmax(dim=-1)
#             (to_qkv): Linear(in_features=1026, out_features=768, bias=False)
#             (to_out): Sequential(
#               (0): Linear(in_features=256, out_features=1026, bias=True)
#               (1): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#         (2): Rearrange('b (ih iw) c -> b c ih iw', ih=7, iw=7)
#       )
#       (ff): Sequential(
#         (0): Rearrange('b c ih iw -> b (ih iw) c')
#         (1): PreNorm(
#           (norm): LayerNorm((1026,), eps=1e-05, elementwise_affine=True)
#           (fn): FeedForward(
#             (net): Sequential(
#               (0): Linear(in_features=1026, out_features=4104, bias=True)
#               (1): GELU(approximate=none)
#               (2): Dropout(p=0.0, inplace=False)
#               (3): Linear(in_features=4104, out_features=1026, bias=True)
#               (4): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#         (2): Rearrange('b (ih iw) c -> b c ih iw', ih=7, iw=7)
#       )
#     )
#   )
#   (pool): AvgPool2d(kernel_size=7, stride=1, padding=0)
#   (fc): Linear(in_features=1026, out_features=200, bias=True)
# )

# %%
#Read picture and predict category of picture
path = 'drive/MyDrive/195A+BSeniorProjectGroupWorks/Datasets/test(christy)/'
testList = os.listdir(path)
for file in testList:
    img = Image.open(path + file)
    img = transform_test(img)
    img.unsqueeze_(0)
    img = Variable(img).to(DEVICE)
    out = model(img)
    # Predict
    _, pred = torch.max(out.data, 1)
    print('Image Name: {}, predict: {}'.format(file, classes[pred.data.item()]))
# Out:
# Image Name: daisy.jpg, predict: daisy
# Image Name: rose.jpg, predict: rose
# Image Name: sunflower.jpg, predict: sunflower
# Image Name: tulip.jpg, predict: tulip
# Image Name: daisy2.jpg, predict: daisy
# Image Name: daisy3.jpg, predict: daisy
# Image Name: rose2.jpg, predict: tulip
# Image Name: rose3.jpg, predict: rose
# Image Name: sunflower2.jpg, predict: sunflower
# Image Name: sunflower3.jpg, predict: sunflower
# Image Name: tulip2.jpg, predict: tulip
# Image Name: tulip3.jpg, predict: tulip
# Image Name: dandelion.jpg, predict: dandelion
# Image Name: dandelion2.jpg, predict: dandelion
# Image Name: dandelion3.jpg, predict: dandelion
# Image Name: sunflower_dl.jpeg, predict: sunflower

# %%
#testing useing test set
path = 'drive/MyDrive/195A+BSeniorProjectGroupWorks/Datasets/Flower_Dataset/flowers_train_test_set/test/daisy/'
testList = os.listdir(path)
for file in testList:
    img = Image.open(path + file)
    img = transform_test(img)
    img.unsqueeze_(0)
    img = Variable(img).to(DEVICE)
    out = model(img)
    # Predict
    _, pred = torch.max(out.data, 1)
    print('Image Name: {}, predict: {}'.format(file, classes[pred.data.item()]))
# Out:
# Image Name: 13583238844_573df2de8e_m.jpg, predict: daisy
# Image Name: 1299501272_59d9da5510_n.jpg, predict: rose
# Image Name: 1286274236_1d7ac84efb_n.jpg, predict: tulip
# Image Name: 10466290366_cc72e33532.jpg, predict: dandelion
# Image Name: 14114116486_0bb6649bc1_m.jpg, predict: daisy
# Image Name: 14087947408_9779257411_n.jpg, predict: daisy
# Image Name: 10559679065_50d2b16f6d.jpg, predict: daisy
# Image Name: 105806915_a9c13e2106_n.jpg, predict: daisy
# Image Name: 14219214466_3ca6104eae_m.jpg, predict: daisy
# Image Name: 34543119581_1fb7e0bd7f_n.jpg, predict: sunflower
# Image Name: 2346726545_2ebce2b2a6.jpg, predict: daisy
# Image Name: 34531542152_c8ba2e0fea_n.jpg, predict: daisy
# Image Name: 34287492780_6dab677857_n.jpg, predict: tulip
# Image Name: 519880292_7a3a6c6b69.jpg, predict: daisy
# Image Name: 147068564_32bb4350cc.jpg, predict: daisy
# Image Name: 521762040_f26f2e08dd.jpg, predict: rose
# Image Name: 15760153042_a2a90e9da5_m.jpg, predict: daisy
# Image Name: 34637970155_a2b917077c_n.jpg, predict: daisy
# Image Name: 33871813063_d7b6bedafe_n.jpg, predict: daisy
# Image Name: 19178753159_a471bf4b6b.jpg, predict: daisy
# Image Name: 34670512115_af22cce24d_n.jpg, predict: daisy
# Image Name: 5608389827_a42a46f760.jpg, predict: daisy
# Image Name: 299129811_d6ebda9970.jpg, predict: daisy
# Image Name: 33879354664_615c72773d_n.jpg, predict: sunflower
# Image Name: 3706420943_66f3214862_n.jpg, predict: daisy
# Image Name: 3661613900_b15ca1d35d_m.jpg, predict: daisy
# Image Name: 3483303007_42e3f90da7.jpg, predict: daisy
# Image Name: 506348009_9ecff8b6ef.jpg, predict: daisy
# Image Name: 4727955343_0bb23ac4ae.jpg, predict: daisy
# Image Name: 22244161124_53e457bb66_n.jpg, predict: daisy
# Image Name: 4222584034_8964cbd3de.jpg, predict: daisy
# Image Name: 5739768868_9f982684f9_n.jpg, predict: daisy
# Image Name: 3379332157_04724f6480.jpg, predict: daisy
# Image Name: 495098110_3a4bb30042_n.jpg, predict: daisy
# Image Name: 34701078235_4a770d14a1_n.jpg, predict: daisy
# Image Name: 21626652132_97e1318bb8_m.jpg, predict: daisy
# Image Name: 34508227161_a9ff840f71_n.jpg, predict: tulip
# Image Name: 5673551_01d1ea993e_n.jpg, predict: rose
# Image Name: 18684594849_7dd3634f5e_n.jpg, predict: daisy
# Image Name: 33885735373_444ba02d9c_n.jpg, predict: dandelion
# Image Name: 5586977262_6b24412805_n.jpg, predict: sunflower
# Image Name: 14866200659_6462c723cb_m.jpg, predict: daisy
# Image Name: 34288158610_6e42406193_n.jpg, predict: daisy
# Image Name: 2642408410_61545fdc83_n.jpg, predict: daisy
# Image Name: 4065883015_4bb6010cb7_n.jpg, predict: daisy
# Image Name: 34518374242_310e7abd54_n.jpg, predict: sunflower
# Image Name: 5623010186_796ca8d29a.jpg, predict: daisy
# Image Name: 34729724865_787c98299d_n.jpg, predict: daisy
# Image Name: 4141147800_813f660b47.jpg, predict: daisy
# Image Name: 2561371688_c80a4fe957_n.jpg, predict: dandelion
# Image Name: 34542837641_10492bf600_n.jpg, predict: daisy
# Image Name: 5809489674_5659b3ae5d_n.jpg, predict: daisy
# Image Name: 8405273313_bef13f6c27_n.jpg, predict: dandelion
# Image Name: 6776075110_1ea7a09dd4_n.jpg, predict: daisy
# Image Name: 7630517248_98fb8bee1f_n.jpg, predict: daisy
# Image Name: 5973488341_50bdf6cee3_n.jpg, predict: daisy
# Image Name: 9120905231_329598304e.jpg, predict: daisy
# Image Name: 5885826924_38fdc6bcaa_n.jpg, predict: daisy
# Image Name: 8671824531_64b816949e_m.jpg, predict: daisy
# Image Name: 9350942387_5b1d043c26_n.jpg, predict: daisy
# Image Name: 5981645737_29eceac291_m.jpg, predict: daisy
# Image Name: 9310226774_d1b8f5d9c9.jpg, predict: daisy
# Image Name: 8127252886_96558c23d1.jpg, predict: dandelion
# Image Name: 7357072446_c21c38c863_n.jpg, predict: daisy
# Image Name: 813445367_187ecf080a_n.jpg, predict: daisy
# Image Name: 6529588249_d9cbe68aab_n.jpg, predict: daisy
# Image Name: 9221345475_67735dbf4f_n.jpg, predict: daisy
# Image Name: 7924174040_444d5bbb8a.jpg, predict: daisy
# Image Name: 5973491805_556bba93cc.jpg, predict: dandelion
# Image Name: 7227973870_806d9d3e42_n.jpg, predict: daisy
# Image Name: 5896680664_641de2de5a_n.jpg, predict: daisy
# Image Name: 8694909523_3ca25d449d_n.jpg, predict: tulip
# Image Name: 8021540573_c56cf9070d_n.jpg, predict: dandelion
# Image Name: 8742143296_fed9fa007c.jpg, predict: dandelion
# Image Name: 5896105367_fa08a65869_n.jpg, predict: daisy
# Image Name: 754248840_95092de274.jpg, predict: daisy
# Image Name: 8759177308_951790e00d_m.jpg, predict: daisy

# %%
#testing useing test set
path = 'drive/MyDrive/195A+BSeniorProjectGroupWorks/Datasets/Flower_Dataset/flowers_train_test_set/test/tulip/'
testList = os.listdir(path)
for file in testList:
    img = Image.open(path + file)
    img = transform_test(img)
    img.unsqueeze_(0)
    img = Variable(img).to(DEVICE)
    out = model(img)
    # Predict
    _, pred = torch.max(out.data, 1)
    print('Image Name: {}, predict: {}'.format(file, classes[pred.data.item()]))
# Out:
# Image Name: 113291410_1bdc718ed8_n.jpg, predict: tulip
# Image Name: 14069914777_b10856aaf7_n.jpg, predict: tulip
# Image Name: 12916441224_2ed63596f8_n.jpg, predict: tulip
# Image Name: 16677542612_a78a8ca8b3_m.jpg, predict: tulip
# Image Name: 14861513337_4ef0bfa40d.jpg, predict: tulip
# Image Name: 13530786873_0d34880300_n.jpg, predict: tulip
# Image Name: 14009216519_b608321cf2_n.jpg, predict: tulip
# Image Name: 155097272_70feb13184.jpg, predict: tulip
# Image Name: 13514131694_d91da4f4fc.jpg, predict: dandelion
# Image Name: 17324469461_2b318aff8d_m.jpg, predict: tulip
# Image Name: 142235017_07816937c6.jpg, predict: tulip
# Image Name: 19317019453_8b24740faf_n.jpg, predict: sunflower
# Image Name: 17189456156_6fc1067831.jpg, predict: tulip
# Image Name: 112951086_150a59d499_n.jpg, predict: tulip
# Image Name: 133692329_c1150ed811_n.jpg, predict: tulip
# Image Name: 3502632842_791dd4be18_n.jpg, predict: tulip
# Image Name: 17291908295_dc7d45ae9b_n.jpg, predict: tulip
# Image Name: 112428665_d8f3632f36_n.jpg, predict: tulip
# Image Name: 20435554843_ba6862f923_n.jpg, predict: tulip
# Image Name: 17146928665_600fa3a1f1_n.jpg, predict: tulip
# Image Name: 17994129033_bbd0acba62_n.jpg, predict: tulip
# Image Name: 21084189635_425ca69aa0_n.jpg, predict: tulip
# Image Name: 13510068773_c925c5517c.jpg, predict: tulip
# Image Name: 14127532150_112823a8f6.jpg, predict: tulip
# Image Name: 3254533919_cb0b8af26c.jpg, predict: tulip
# Image Name: 20282921225_6033da8cd5_n.jpg, predict: rose
# Image Name: 16645809126_613b1e3ebe_m.jpg, predict: tulip
# Image Name: 16907559551_05ded87fb2_n.jpg, predict: tulip
# Image Name: 16680998737_6f6225fe36.jpg, predict: dandelion
# Image Name: 14275234071_6e6f473356.jpg, predict: tulip
# Image Name: 20910465721_fd8dcc8fcc_n.jpg, predict: tulip
# Image Name: 16265876844_0a149c4f76.jpg, predict: tulip
# Image Name: 13953090784_0c7d7a904e.jpg, predict: tulip
# Image Name: 19892369060_d1298a9816_n.jpg, predict: tulip
# Image Name: 13976191172_6f23a0b313.jpg, predict: tulip
# Image Name: 17408197905_829c4d7940_m.jpg, predict: tulip
# Image Name: 14084211971_0f921f11fe_n.jpg, predict: rose
# Image Name: 19693717158_af4afcffd2_n.jpg, predict: rose
# Image Name: 3502974120_9f1eceaf8b_n.jpg, predict: tulip
# Image Name: 3446285408_4be9c0fded_m.jpg, predict: tulip
# Image Name: 25759191500_1c0da35828_n.jpg, predict: tulip
# Image Name: 21065300966_6be98a8cd0_n.jpg, predict: tulip
# Image Name: 19860199064_35c14fa8c7_n.jpg, predict: tulip
# Image Name: 14116780333_7836f4448c.jpg, predict: daisy
# Image Name: 16930105456_8b826dc4a8_n.jpg, predict: tulip
# Image Name: 8713387500_6a9138b41b_n.jpg, predict: tulip
# Image Name: 4579079143_f65b39dd9f.jpg, predict: tulip
# Image Name: 8605564823_7a59d3d92a.jpg, predict: tulip
# Image Name: 8687675254_c93f50d8b0_m.jpg, predict: tulip
# Image Name: 5682463466_d3e641cb8b.jpg, predict: tulip
# Image Name: 5718513240_e84d5a7e89_n.jpg, predict: rose
# Image Name: 6931715360_34edc5a372_m.jpg, predict: rose
# Image Name: 466409031_4c10294db5_m.jpg, predict: tulip
# Image Name: 5208680166_c4372477ef_n.jpg, predict: tulip
# Image Name: 8759594528_2534c0ec65_n.jpg, predict: tulip
# Image Name: 7166550328_de0d73cfa9_n.jpg, predict: tulip
# Image Name: 4508346090_a27b988f79_n.jpg, predict: tulip
# Image Name: 4353419275_79d3904074_n.jpg, predict: tulip
# Image Name: 7003964080_4566470798_n.jpg, predict: rose
# Image Name: 7166564830_8b34a3fd35_n.jpg, predict: tulip
# Image Name: 8722514702_7ecc68691c.jpg, predict: rose
# Image Name: 7166554924_432aaae4b2_n.jpg, predict: tulip
# Image Name: 7166539842_43b7e02883.jpg, predict: tulip
# Image Name: 5674167473_ac696c8989_n.jpg, predict: tulip
# Image Name: 7145978709_2d1596f462.jpg, predict: rose
# Image Name: 8697784345_e75913d220.jpg, predict: tulip
# Image Name: 4550117239_5907aaba4c.jpg, predict: tulip
# Image Name: 738207467_fc59cfcd9b_z.jpg, predict: tulip
# Image Name: 4579128789_1561575458_n.jpg, predict: tulip
# Image Name: 391477275_7c2f50a1a7_m.jpg, predict: tulip
# Image Name: 5524946579_307dc74476.jpg, predict: tulip
# Image Name: 5717950291_af2aed83d8_n.jpg, predict: tulip
# Image Name: 5691090657_2f1e9bf49e_n.jpg, predict: tulip
# Image Name: 4562423077_00b16240dc_n.jpg, predict: tulip
# Image Name: 3990989735_59e2751151_n.jpg, predict: tulip
# Image Name: 4681062529_36186617d9.jpg, predict: tulip
# Image Name: 8688502760_1c8d6de921_m.jpg, predict: tulip
# Image Name: 7002703410_3e97b29da5_n.jpg, predict: tulip
# Image Name: 8562853756_73778dac25_n.jpg, predict: tulip
# Image Name: 8713391394_4b679ea1e3_n.jpg, predict: tulip
# Image Name: 503770507_f397245a6a.jpg, predict: rose
# Image Name: 7166570828_7c26ca5766_n.jpg, predict: rose
# Image Name: 5644061265_e02135f028_n.jpg, predict: dandelion
# Image Name: 8712266605_3787e346cd_n.jpg, predict: tulip
# Image Name: 5565089564_a30c318f44.jpg, predict: tulip
# Image Name: 4575963749_2418ff8768.jpg, predict: tulip
# Image Name: 8713407768_f880df361f.jpg, predict: tulip
# Image Name: 420216121_3ee33723d7_m.jpg, predict: daisy
# Image Name: 4546316433_202cc68c55.jpg, predict: rose
# Image Name: 7166560822_27b1d1d132_n.jpg, predict: dandelion
# Image Name: 5634767665_0ae724774d.jpg, predict: tulip
# Image Name: 6325571510_7544b27e57_n.jpg, predict: rose
# Image Name: 8729501081_b993185542_m.jpg, predict: daisy
# Image Name: 7166646966_41d83cd703.jpg, predict: tulip
# Image Name: 8712282563_3819afb7bc.jpg, predict: tulip
# Image Name: 7166635566_ee240b5408_n.jpg, predict: tulip
# Image Name: 5755467567_903c31e3d0.jpg, predict: tulip
# Image Name: 3991423020_9aaf2b5974_n.jpg, predict: tulip
# Image Name: 8908062479_449200a1b4.jpg, predict: tulip

# %%
#testing useing test set
path = 'drive/MyDrive/195A+BSeniorProjectGroupWorks/Datasets/Flower_Dataset/flowers_train_test_set/test/rose/'
testList = os.listdir(path)
for file in testList:
    img = Image.open(path + file)
    img = transform_test(img)
    img.unsqueeze_(0)
    img = Variable(img).to(DEVICE)
    out = model(img)
    # Predict
    _, pred = torch.max(out.data, 1)
    print('Image Name: {}, predict: {}'.format(file, classes[pred.data.item()]))
# Out:
# Image Name: 14154164774_3b39d36778.jpg, predict: tulip
# Image Name: 15818051327_9a44bf6244_n.jpg, predict: rose
# Image Name: 18464075576_4e496e7d42_n.jpg, predict: tulip
# Image Name: 22506717337_0fd63e53e9.jpg, predict: rose
# Image Name: 14870567200_80cda4362e_n.jpg, predict: tulip
# Image Name: 15965652160_de91389965_m.jpg, predict: rose
# Image Name: 18490508225_0fc630e963_n.jpg, predict: tulip
# Image Name: 1775233884_12ff5a124f.jpg, predict: rose
# Image Name: 18486124712_17ebe7559b_n.jpg, predict: rose
# Image Name: 123128873_546b8b7355_n.jpg, predict: rose
# Image Name: 20622485918_90fc000c86_n.jpg, predict: dandelion
# Image Name: 14414117598_cf70df30de.jpg, predict: rose
# Image Name: 14172324538_2147808483_n.jpg, predict: tulip
# Image Name: 12238827553_cf427bfd51_n.jpg, predict: rose
# Image Name: 15699509054_d3e125286f_n.jpg, predict: rose
# Image Name: 17305246720_1866d6303b.jpg, predict: rose
# Image Name: 14687731322_5613f76353.jpg, predict: tulip
# Image Name: 1461381091_aaaa663bbe_n.jpg, predict: tulip
# Image Name: 12243069253_e512464095_n.jpg, predict: rose
# Image Name: 5349865556_e3263fbdc0_n.jpg, predict: rose
# Image Name: 5336558870_22d0a6a318_n.jpg, predict: rose
# Image Name: 8437935944_aab997560a_n.jpg, predict: rose
# Image Name: 4612833069_8e48b47aa4_n.jpg, predict: tulip
# Image Name: 7345657862_689366e79a.jpg, predict: rose
# Image Name: 8035908422_87220425d2_n.jpg, predict: rose
# Image Name: 7409458444_0bfc9a0682_n.jpg, predict: rose
# Image Name: 4279990882_031482f8b6_n.jpg, predict: tulip
# Image Name: 5002446614_bb2a5b4bc1_n.jpg, predict: dandelion
# Image Name: 2777518561_105abc8cfc_n.jpg, predict: tulip
# Image Name: 5002452394_22896fb9df_n.jpg, predict: rose
# Image Name: 9159362388_c6f4cf3812_n.jpg, predict: rose
# Image Name: 7481118556_6c209b9b7d_n.jpg, predict: rose
# Image Name: 3634244527_e72c47842c_n.jpg, predict: tulip
# Image Name: 5537794501_a0767743fd_n.jpg, predict: rose
# Image Name: 9216323421_f737c1d50e.jpg, predict: rose
# Image Name: 5502949025_96d11a17ff_n.jpg, predict: rose
# Image Name: 8926641787_d2515dfe8f_m.jpg, predict: tulip
# Image Name: 8301512319_45185c447f_n.jpg, predict: tulip
# Image Name: 685724528_6cd5cbe203.jpg, predict: daisy
# Image Name: 6347846935_51e3dc2481_n.jpg, predict: rose
# Image Name: 5234278003_d827fcd73b_m.jpg, predict: rose
# Image Name: 3630246240_4fee9a33db.jpg, predict: rose
# Image Name: 6231418894_7946a7712b_n.jpg, predict: rose
# Image Name: 8096324039_4db2555490.jpg, predict: tulip
# Image Name: 4735314389_94fe1b2a9f_n.jpg, predict: rose
# Image Name: 7470985688_c1ee9105fa_n.jpg, predict: rose
# Image Name: 8181940917_1ac63937d5_n.jpg, predict: rose
# Image Name: 5001847255_34ff6146ec_n.jpg, predict: rose
# Image Name: 410425647_4586667858.jpg, predict: dandelion
# Image Name: 9355706808_a9a723a8e8_n.jpg, predict: rose
# Image Name: 4694341873_65fe187a4e_n.jpg, predict: rose
# Image Name: 5897035797_e67bf68124_n.jpg, predict: rose
# Image Name: 5349254467_388ff94f8b_n.jpg, predict: rose
# Image Name: 5529341024_0c35f2657d.jpg, predict: tulip
# Image Name: 7456198272_f5d0c6bc7e_n.jpg, predict: rose
# Image Name: 3276552939_8c31b22d3e.jpg, predict: rose
# Image Name: 33184832190_e5411d91a4_n.jpg, predict: tulip
# Image Name: 7471890996_e61b134867_n.jpg, predict: rose
# Image Name: 4279989256_9a48c0d194_n.jpg, predict: tulip
# Image Name: 2491600761_7e9d6776e8_m.jpg, predict: rose
# Image Name: 5694090698_1f0c218250_n.jpg, predict: rose
# Image Name: 7461897398_0053093145_n.jpg, predict: rose
# Image Name: 4608559939_3487bf3b62_n.jpg, predict: rose
# Image Name: 8742493689_fb852f0228_n.jpg, predict: tulip
# Image Name: 5001844777_d9e1968119_n.jpg, predict: rose
# Image Name: 7474126248_889a026929_n.jpg, predict: rose
# Image Name: 6732261031_861a1026fa_n.jpg, predict: dandelion
# Image Name: 6690926183_afedba9f15_n.jpg, predict: rose
# Image Name: 3873271620_1d9d314f01_n.jpg, predict: rose
# Image Name: 6163179241_f093f45d95_n.jpg, predict: rose
# Image Name: 4764674741_82b8f93359_n.jpg, predict: rose
# Image Name: 394990940_7af082cf8d_n.jpg, predict: rose
# Image Name: 5335946155_be70e11cf2_n.jpg, predict: daisy
# Image Name: 33568244695_7ec846bcc6_n.jpg, predict: rose
# Image Name: 8279801891_5369a6c3c1_n.jpg, predict: tulip
# Image Name: 5002449706_647ffe5249_n.jpg, predict: rose
# Image Name: 7456914664_cdee3170c5_n.jpg, predict: rose
# Image Name: 5349250331_05501d6557_n.jpg, predict: rose
# Image Name: 563847503_89e9756c80.jpg, predict: rose

# %%
#testing useing test set
path = 'drive/MyDrive/195A+BSeniorProjectGroupWorks/Datasets/Flower_Dataset/flowers_train_test_set/test/dandelion/'
testList = os.listdir(path)
for file in testList:
    img = Image.open(path + file)
    img = transform_test(img)
    img.unsqueeze_(0)
    img = Variable(img).to(DEVICE)
    out = model(img)
    # Predict
    _, pred = torch.max(out.data, 1)
    print('Image Name: {}, predict: {}'.format(file, classes[pred.data.item()]))
# Out:
# Image Name: 14362539701_cf19e588ca.jpg, predict: dandelion
# Image Name: 14396023703_11c5dd35a9.jpg, predict: dandelion
# Image Name: 14021281124_89cc388eac_n.jpg, predict: dandelion
# Image Name: 17570530696_6a497298ee_n.jpg, predict: dandelion
# Image Name: 18996965033_1d92e5c99e.jpg, predict: dandelion
# Image Name: 17276354745_2e312a72b5_n.jpg, predict: dandelion
# Image Name: 11768468623_9399b5111b_n.jpg, predict: dandelion
# Image Name: 142813254_20a7fd5fb6_n.jpg, predict: dandelion
# Image Name: 14457225751_645a3784fd_n.jpg, predict: dandelion
# Image Name: 18010259565_d6aae33ca7_n.jpg, predict: dandelion
# Image Name: 14171812905_8b81d50eb9_n.jpg, predict: dandelion
# Image Name: 18479635994_83f93f4120.jpg, predict: dandelion
# Image Name: 15819121091_26a5243340_n.jpg, predict: dandelion
# Image Name: 14761980161_2d6dbaa4bb_m.jpg, predict: dandelion
# Image Name: 1297972485_33266a18d9.jpg, predict: dandelion
# Image Name: 14368895004_c486a29c1e_n.jpg, predict: dandelion
# Image Name: 138132145_782763b84f_m.jpg, predict: dandelion
# Image Name: 14884028290_a1344eb446.jpg, predict: dandelion
# Image Name: 17020815734_81e8db8008_m.jpg, predict: dandelion
# Image Name: 17457028309_95514c8d02_n.jpg, predict: dandelion
# Image Name: 14845607659_1be18c5d7f.jpg, predict: dandelion
# Image Name: 155646858_9a8b5e8fc8.jpg, predict: dandelion
# Image Name: 17244252705_328e0bcda6.jpg, predict: dandelion
# Image Name: 151385301_153eacf6b5_n.jpg, predict: dandelion
# Image Name: 14128835667_b6a916222c.jpg, predict: dandelion
# Image Name: 141340262_ca2e576490.jpg, predict: dandelion
# Image Name: 14829055_2a2e646a8f_m.jpg, predict: dandelion
# Image Name: 17047385027_8fd510e164_n.jpg, predict: dandelion
# Image Name: 12998979765_3de89e7195_n.jpg, predict: dandelion
# Image Name: 2076141453_c63801962a_m.jpg, predict: dandelion
# Image Name: 17346385582_7ba433dbbe.jpg, predict: dandelion
# Image Name: 18996760154_58d3c48604.jpg, predict: dandelion
# Image Name: 4571923094_b9cefa9438_n.jpg, predict: dandelion
# Image Name: 493696003_f93ffb3abd_n.jpg, predict: dandelion
# Image Name: 463736819_f779800165.jpg, predict: daisy
# Image Name: 2622697182_ea4aff29dd_n.jpg, predict: dandelion
# Image Name: 3696596109_4c4419128a_m.jpg, predict: dandelion
# Image Name: 26741270544_f44f3a1b19_n.jpg, predict: dandelion
# Image Name: 5607256228_2294c201b3.jpg, predict: dandelion
# Image Name: 2472641499_cbe617a93d.jpg, predict: dandelion
# Image Name: 2449852402_45d12b9875_n.jpg, predict: dandelion
# Image Name: 34690477346_6af75b993b_n.jpg, predict: dandelion
# Image Name: 5757012454_c37f305b73.jpg, predict: dandelion
# Image Name: 458011386_ec89115a19.jpg, predict: dandelion
# Image Name: 34725992285_21cb05733a_n.jpg, predict: dandelion
# Image Name: 2535769822_513be6bbe9.jpg, predict: dandelion
# Image Name: 4632863567_5f9af7de97_n.jpg, predict: dandelion
# Image Name: 34582964591_dc9f160fce_n.jpg, predict: dandelion
# Image Name: 4669006062_6b3d260037_n.jpg, predict: dandelion
# Image Name: 2490828907_5094017933_m.jpg, predict: dandelion
# Image Name: 3357432116_b3dce6fed3_n.jpg, predict: dandelion
# Image Name: 4134441089_c8c1e6132a.jpg, predict: dandelion
# Image Name: 4696437766_85952d0196.jpg, predict: dandelion
# Image Name: 2683330456_0f7bbce110_m.jpg, predict: dandelion
# Image Name: 4669815582_0a994fb4fd_m.jpg, predict: dandelion
# Image Name: 455728598_c5f3e7fc71_m.jpg, predict: dandelion
# Image Name: 3688128868_031e7b53e1_n.jpg, predict: rose
# Image Name: 5613466853_e476bb080e.jpg, predict: daisy
# Image Name: 34351602790_37234e2dae_n.jpg, predict: dandelion
# Image Name: 3998275481_651205e02d.jpg, predict: dandelion
# Image Name: 26004221274_74900d17e1_n.jpg, predict: dandelion
# Image Name: 2457473644_5242844e52_m.jpg, predict: dandelion
# Image Name: 5674707921_1ffd141bab_n.jpg, predict: dandelion
# Image Name: 4944731313_023a0508fd_n.jpg, predict: sunflower
# Image Name: 29535628436_2e79a9628d_n.jpg, predict: dandelion
# Image Name: 4573204385_9b71e96b35_m.jpg, predict: daisy
# Image Name: 4632761610_768360d425.jpg, predict: dandelion
# Image Name: 3554992110_81d8c9b0bd_m.jpg, predict: dandelion
# Image Name: 4510350093_3700064215.jpg, predict: dandelion
# Image Name: 2674176237_e265ea64cc_n.jpg, predict: dandelion
# Image Name: 34587934371_1a0429111e_n.jpg, predict: dandelion
# Image Name: 4151883194_e45505934d_n.jpg, predict: dandelion
# Image Name: 34540904752_ae86e5f6ce_n.jpg, predict: dandelion
# Image Name: 33885269993_3968e1aacc_n.jpg, predict: dandelion
# Image Name: 2753166154_0cb51a127b.jpg, predict: dandelion
# Image Name: 3664916269_29f07c7c7b.jpg, predict: dandelion
# Image Name: 2257649769_deaf97e2c9_n.jpg, predict: dandelion
# Image Name: 34721329895_529f999fb6_n.jpg, predict: dandelion
# Image Name: 3857059749_fe8ca621a9.jpg, predict: dandelion
# Image Name: 3365850019_8158a161a8_n.jpg, predict: dandelion
# Image Name: 478851599_25bfd70605_n.jpg, predict: dandelion
# Image Name: 2512977446_ac498955ee.jpg, predict: dandelion
# Image Name: 4254850910_0610224342_n.jpg, predict: dandelion
# Image Name: 477207005_6327db8393_m.jpg, predict: dandelion
# Image Name: 34560984002_254f326f12_n.jpg, predict: dandelion
# Image Name: 2470731130_089b8514f6_n.jpg, predict: dandelion
# Image Name: 34323484476_6406ee1e37_n.jpg, predict: dandelion
# Image Name: 7808545612_546cfca610_m.jpg, predict: dandelion
# Image Name: 7015947703_11b30c20c9_n.jpg, predict: rose
# Image Name: 6019234426_d25ea1230a_m.jpg, predict: dandelion
# Image Name: 7162551630_3647eb9254.jpg, predict: dandelion
# Image Name: 8733226215_161309f8ec.jpg, predict: dandelion
# Image Name: 5862288632_1df5eb6dd0.jpg, predict: dandelion
# Image Name: 8978962053_0727b41d26.jpg, predict: dandelion
# Image Name: 9300335851_cdf1cef7a9.jpg, predict: dandelion
# Image Name: 8797114213_103535743c_m.jpg, predict: dandelion
# Image Name: 8805314187_1aed702082_n.jpg, predict: dandelion
# Image Name: 5772194932_60b833091f.jpg, predict: dandelion
# Image Name: 8223968_6b51555d2f_n.jpg, predict: dandelion
# Image Name: 8497389500_45636fdd14.jpg, predict: dandelion
# Image Name: 8223949_2928d3f6f6_n.jpg, predict: dandelion
# Image Name: 7243478942_30bf542a2d_m.jpg, predict: dandelion
# Image Name: 7083589767_2859993846_n.jpg, predict: dandelion
# Image Name: 6983113346_21551e1b52_n.jpg, predict: dandelion
# Image Name: 7132677385_bcbdcc6001.jpg, predict: daisy
# Image Name: 8083321316_f62ea76f72_n.jpg, predict: dandelion
# Image Name: 8011324555_375b7b5b0a.jpg, predict: dandelion
# Image Name: Copy of 8969938579_4c2032dd96_n.jpg, predict: dandelion
# Image Name: Copy of 8701999625_8d83138124.jpg, predict: dandelion
# Image Name: Copy of 7247192002_39b79998f0_n.jpg, predict: dandelion
# Image Name: Copy of 7132605107_f5e033d725_n.jpg, predict: dandelion

# %%
#testing useing test set
path = 'drive/MyDrive/195A+BSeniorProjectGroupWorks/Datasets/Flower_Dataset/flowers_train_test_set/test/sunflower/'
testList = os.listdir(path)
for file in testList:
    img = Image.open(path + file)
    img = transform_test(img)
    img.unsqueeze_(0)
    img = Variable(img).to(DEVICE)
    out = model(img)
    # Predict
    _, pred = torch.max(out.data, 1)
    print('Image Name: {}, predict: {}'.format(file, classes[pred.data.item()]))
# Out:
# Image Name: 12323859023_447387dbf0_n.jpg, predict: dandelion
# Image Name: 10541580714_ff6b171abd_n.jpg, predict: sunflower
# Image Name: 12282924083_fb80aa17d4_n.jpg, predict: sunflower
# Image Name: 3946535195_9382dcb951_n.jpg, predict: dandelion
# Image Name: 2807106374_f422b5f00c.jpg, predict: sunflower
# Image Name: 3146795631_d062f233c1.jpg, predict: sunflower
# Image Name: 20704967595_a9c9b8d431.jpg, predict: sunflower
# Image Name: 14646282112_447cc7d1f9.jpg, predict: sunflower
# Image Name: 1484598527_579a272f53.jpg, predict: dandelion
# Image Name: 3001536784_3bfd101b23_n.jpg, predict: sunflower
# Image Name: 14858674096_ed0fc1a130.jpg, predict: sunflower
# Image Name: 20621698991_dcb323911d.jpg, predict: sunflower
# Image Name: 14921668662_3ffc5b9db3_n.jpg, predict: sunflower
# Image Name: 15218421476_9d5f38e732_m.jpg, predict: sunflower
# Image Name: 22183521655_56221bf2a4_n.jpg, predict: sunflower
# Image Name: 4664767140_fe01231322_n.jpg, predict: sunflower
# Image Name: 23356825566_f5885875f2.jpg, predict: sunflower
# Image Name: 4271193206_666ef60aa0_m.jpg, predict: sunflower
# Image Name: 3884437548_ca8c36be3f_n.jpg, predict: sunflower
# Image Name: 3596902268_049e33a2cb_n.jpg, predict: sunflower
# Image Name: 4489516263_e49fe82637_n.jpg, predict: sunflower
# Image Name: 19504937128_a4ae90fcbd_m.jpg, predict: sunflower
# Image Name: 3946535709_78613461cb_n.jpg, predict: sunflower
# Image Name: 15145607875_e87204d78c_n.jpg, predict: sunflower
# Image Name: 3846907701_e13b66aa87.jpg, predict: sunflower
# Image Name: 15493195788_60530f2398_m.jpg, predict: sunflower
# Image Name: 20407896403_a50fef58ac_n.jpg, predict: sunflower
# Image Name: 3665455426_9cd1c3af4a_n.jpg, predict: sunflower
# Image Name: 29972905_4cc537ff4b_n.jpg, predict: dandelion
# Image Name: 14348961225_09bd803317_n.jpg, predict: sunflower
# Image Name: 19710076021_f5bb162540.jpg, predict: sunflower
# Image Name: 3912497870_a2f91c3a65_n.jpg, predict: sunflower
# Image Name: 265450085_6e9f276e2e.jpg, predict: dandelion
# Image Name: 14460075029_5cd715bb72_m.jpg, predict: sunflower
# Image Name: 5018120483_cc0421b176_m.jpg, predict: sunflower
# Image Name: 6606823367_e89dc52a95_n.jpg, predict: sunflower
# Image Name: 6482016439_b0d06dac04.jpg, predict: sunflower
# Image Name: 6074427492_1b5bab7848_n.jpg, predict: sunflower
# Image Name: 6104713425_8a3277e34a.jpg, predict: sunflower
# Image Name: 9375675309_987d32f99e_n.jpg, predict: sunflower
# Image Name: 6606749757_b98a4ba403.jpg, predict: sunflower
# Image Name: 9558628596_722c29ec60_m.jpg, predict: sunflower
# Image Name: 9448615838_04078d09bf_n.jpg, predict: sunflower
# Image Name: 7935826214_9b57628203_m.jpg, predict: sunflower
# Image Name: 9206376642_8348ba5c7a.jpg, predict: sunflower
# Image Name: 8014735546_3db46bb1fe_n.jpg, predict: tulip
# Image Name: 4745991955_6804568ae0_n.jpg, predict: dandelion
# Image Name: 9610374042_bb16cded3d.jpg, predict: sunflower
# Image Name: 5933438337_b26a81ea81_n.jpg, predict: sunflower
# Image Name: 9246304620_768d1f54d7_n.jpg, predict: sunflower
# Image Name: 8014734302_65c6e83bb4_m.jpg, predict: sunflower
# Image Name: 4848279231_c4960e28b2_n.jpg, predict: sunflower
# Image Name: 7791014076_07a897cb85_n.jpg, predict: sunflower
# Image Name: 5991628433_e1d853e40d_n.jpg, predict: sunflower
# Image Name: 5970868068_fe1c8b282e_n.jpg, predict: rose
# Image Name: 6250692311_cb60c85ee9_n.jpg, predict: sunflower
# Image Name: 7586498522_4dcab1c8d2_m.jpg, predict: dandelion
# Image Name: 9216286876_289a4779f7.jpg, predict: sunflower
# Image Name: 5004121118_e9393e60d0_n.jpg, predict: sunflower
# Image Name: 7176723954_e41618edc1_n.jpg, predict: sunflower
# Image Name: 4878447831_e904c60cf8_n.jpg, predict: sunflower
# Image Name: 9511172241_8aee411e2e.jpg, predict: sunflower
# Image Name: 9681915384_b3b646dc92_m.jpg, predict: sunflower
# Image Name: 7510285306_ba8f80c382_n.jpg, predict: sunflower
# Image Name: 8929288228_6795bcb1fe.jpg, predict: sunflower
# Image Name: 9216286162_6ceefdd1b4_m.jpg, predict: sunflower
# Image Name: 8265023280_713f2c69d0_m.jpg, predict: sunflower
# Image Name: 6133988570_9dc778e622_m.jpg, predict: sunflower
# Image Name: 8368015811_2893411cf7_n.jpg, predict: sunflower
# Image Name: 4940287066_385afd9c18_m.jpg, predict: sunflower
# Image Name: 4746668678_0e2693b1b9_n.jpg, predict: sunflower
# Image Name: 9610098411_f1613c8e14.jpg, predict: sunflower
# Image Name: 6482016425_d8fab362f6.jpg, predict: sunflower
# Image Name: 9460336948_6ae968be93.jpg, predict: sunflower

# %% [markdown]
# Note: larger dataset yields worse result
# Why?
# *Figure this out and make it a novelty point*
#
# Priority: expand dataset

# %%
# # Show input and output of a directly uploaded picture
# from google.colab import files
# uploaded = files.upload()
# # Show the image
# from matplotlib import pyplot as plt
# input = plt.imread("")
# img = plt.imshow(input)
# # Resize the image
# from skimage.transform import resize
# resized_img = resize(input, (32,32,3))
# img = plt.imshow(resized_img)
# # Get model predictions
# img = transform_test(img)
# img.unsqueeze_(0)
# out = model(img)
# _, pred = torch.max(out.data, 1)
# print('Image Name: {}, predict: {}'.format(file, classes[pred.data.item()]))
